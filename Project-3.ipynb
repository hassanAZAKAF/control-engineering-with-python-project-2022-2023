# %% [markdown]
# # Wheelchair Control
#
# ![](images/wheelchair.jpg)

# %% [markdown]
# ### Python Dependencies

# %%
from numpy import *
from numpy.linalg import *

from scipy.linalg import *
from scipy.integrate import *
from scipy.signal import *

from matplotlib.pyplot import *

# %% [markdown]
# Step 1 - Wheelchair Planar Model
# ================================

# %% [markdown]
# ### Introduction

# %% [markdown]
# We consider a simple model of a wheelchair evolving in the plane. It is mainly made of
#
#   - A frame ; from above, its most visible component is the seat. We assume that it is a square,
#
#   - Two fixed wheels (their orientation with respect to the frame does not change).
#     They are parallel and located at opposite ends of the seat.
#
# We assume that the seat backrest is on top of the wheels common axis.
#
#
# Let $(0, e_x, e_y)$ be a direct orthonormal frame of the plane. We denote
#
#   - $(x, y)$ the coordinates of the wheel axis center in the orthonormal and
#   - $\theta$ the angle of the wheels direction with respect to vector $e_x$ ; with $\theta = 0$ when the front of the wheelchait faces the right ($e_x$) and $\theta = \pi/2$ when it faces upwards ($e_y$).
#
#   - $\phi_l$ and $\phi_r$ the rotation angles of the left and right wheel respectively ; by convention, when these angles increase, the wheelchair moves forward.

# %% [markdown]
# ### Parameter Definition

# %% [markdown]
# From now on, we assume that the seat side length is $L = 50 \mbox{ cm}$ and the wheel radius is $R_w = 30 \mbox{ cm}$.
#
# 🧩 Define the corresponding Python variables `L` and `Rw` (express every length in meters, and more generally in the sequel, always use the [international standard of units](https://en.wikipedia.org/wiki/SI_derived_unit)) for numerical values.

# %%
# 🔓
L = 50 / 100
Rw = 30 / 100

# %% [markdown]
# ### Graphical Representation
#
# 🧩 Implement a function `draw_wheelchair` with arguments `x`, `y` and `theta` that draws a simple geometric model of the wheelchair (with seat and fixed wheels) in the plane (top view) for arbitrary values of $(x, y)$ and $\theta$.
#
# 🗝️ **Hint.** Use the function `plot` of `matplotlib.pyplot`.

# %%
# 🔓
def draw_wheelchair(x, y, theta):
    translation = array([[x], [y]])
    rotation = array([
        [cos(theta), -sin(theta)], 
        [sin(theta),  cos(theta)]
    ])

    # Seat
    corners = [[0, -L/2], [L, -L/2], [L, +L/2], [0, L/2]]
    corners += [corners[0]]
    corners = array(corners).T
    corners = rotation @ corners + translation
    xc = corners[0]
    yc = corners[1]
    fill(xc, yc, color="#868e96", zorder=10)
    
    # Fixed Wheels
    wheel_left_xy_start = rotation @ [[-Rw], [-L/2]] + translation 
    wheel_left_xy_end = rotation @ [[Rw], [-L/2]] + translation
    plot([wheel_left_xy_start[0], wheel_left_xy_end[0]], [wheel_left_xy_start[1], wheel_left_xy_end[1]], color="black",linewidth=5, zorder=20)

    wheel_right_xy_start = rotation @ [[-Rw], [+L/2]] + translation
    wheel_right_xy_end = rotation @ [[Rw], [L/2]] + translation
    plot([wheel_right_xy_start[0], wheel_right_xy_end[0]], [wheel_right_xy_start[1], wheel_right_xy_end[1]], color="black", linewidth=5, zorder=20)

# %% [markdown]
# 🧩 Represent the wheelchair when $(x, y, \theta) = (0, 0, 0), (2, 2, \pi/2), (0, 4, \pi), (-2, 2, 3\pi/2)$.
#
# 🗝️ **Hint.** Use the following `draw_arena` function beforehand.

# %%
def draw_arena(xmin, xmax, ymin, ymax):
    wh_ratio = (xmax - xmin) / (ymax - ymin)
    figsize = fig_width, fig_height = 16, 16 / wh_ratio
    figure(figsize=figsize)
    axes = gca()
    axes.axis([xmin, xmax, ymin, ymax])
    axes.set_aspect(1)
    xticks(arange(xmin, xmax+1, 1))
    yticks(arange(ymin, ymax+1, 1))
    grid(True)

# %%
# 🔓
draw_arena(-5, 5, -1, 5)
draw_wheelchair(0, 0, 0)
draw_wheelchair(2, 2, pi/2)
draw_wheelchair(0, 4, pi)
draw_wheelchair(-2, 2, 3*pi/2)

# %% [markdown]
# ### Kinematic Modeling
#
# We assume that we can control the wheels angular velocities $\omega_l = \dot{\phi}_l$ and $\omega_r = \dot{\phi}_r$ (this is a *kinematic* model of the wheelchair).
# We also assume that the wheelchair fixed wheels roll without slipping.
#
# 🧩 Establish the differential equations that relate $\dot{x}$,
# $\dot{y}$ and $\dot{\theta}$ with $\omega_l$ and $\omega_r$.

# %% [markdown]
# 🔓
# $$
# \begin{array}{rcl}
# \dot{x} &=& R_w  \frac{\omega_l + \omega_r}{2} \cos \theta \\
# \dot{y} &=& R_w  \frac{\omega_l + \omega_r}{2} \sin \theta \\
# \dot{\theta} &=& R_w  \frac{\omega_r - \omega_l}{L} \\
# \end{array}
# $$

# %% [markdown]
# ### Analysis
#
# 🧩 Show that if $\omega_l$ and $\omega_r$ are continuously differentiable functions of $(x, y, \theta)$ (which includes the case of constant inputs), this system is well-posed.

# %% [markdown]
# 🔓 The vector field is continuously differentiable as a composition of continuously differentiable functions, thus the IVP is well-posed.

# %% [markdown]
# 🧩 Show that if $\omega_l$ and $\omega_r$ are constants, the maximal solution associated to any initial state is global. Is is still true of $\omega_l$ and $\omega_r$ are arbitrary continuously differentiable functions of $(x, y, \theta)$ ?

# %% [markdown]
# 🔓 When the inputs are constant, it's pretty easy to prove that the derivatives of $x$, $y$ and $\theta$ with respect to $t$ are uniformly bounded ; thus $x$, $y$ and $\theta$ are bounded on any bounded time interval and therefore no finite-time blowup may happen: the maximal solution is global.
#
# The situation is different with state-dependent inputs; for example with $\omega_r = - \omega_l = 0.5 (L/R_w)  \theta^2$, we end up with $\dot{\theta}(t) = \theta(t)^2$ which has a finite-time blowup for some initial values of $\theta$. Thus, the maximal solution may not be global.

# %% [markdown]
# ### Vector Field
#
# In the sequel, `omega` is a function that computes the input vector $\omega := (\omega_l, \omega_r)$ given the time $t$ and $(x, y, \theta)$ (thus, it may depend on the time and/or on the system state if needed). For example:

# %%
def omega(t, xytheta):
    omega_l = (1 - L/4) * pi / Rw
    omega_r = (1 + L/4) * pi / Rw
    return array([omega_l, omega_r])

# %% [markdown]
# 🧩 Implement a function `fun(t, xytheta)` that computes $(\dot{x}, \dot{y}, \dot{\theta})$ given the time $t$ and $(x,y,\theta)$ (and implicitly the inputs $\omega$ computed by the function `omega`).

# %%
# 🔓
def fun(t, xytheta):
    x, y, theta = xytheta
    omega_l, omega_r = omega(t, xytheta)
    dx = Rw * 0.5 * (omega_l + omega_r) * cos(theta)
    dy = Rw * 0.5 * (omega_l + omega_r) * sin(theta)
    dtheta = Rw * (omega_r - omega_l) / L
    return array([dx, dy, dtheta])

# %% [markdown]
# ### Simulation Setup
#
# 🧩 Simulate the wheelchair dynamics for 4 seconds when $(x_0, y_0, \theta_0)(t=0) = (0.0, 0.0, 0.0)$,
# and the wheels velocities are the constants $\omega_l = (1 - L/4)  \pi / R \mbox{ rad/s}$ and $\omega_r = (1 + L/4)  \pi / R_w \mbox{ rad/s}$.
# (Compute the dense outputs.)

# %%
# 🔓
r = solve_ivp(fun=fun, t_span =(0.0, 4.0), y0=[0.0, 0.0, 0.0], dense_output=True)

# %% [markdown]
# 🧩 Use the simulation results to draw the graphs of $x(t)$, $y(t)$ and $\theta(t)$.

# %%
# 🔓
t = linspace(0.0, 4.0, 1000)
x, y, theta = r["sol"](t)
fig=figure(figsize=(15, 15))
ax1, ax2 = fig.subplots(2, 1, sharex=True)
ax1.grid(True)
ax1.plot(t, x, label="$x(t)$")
ax1.plot(t, y, label="$y(t)$")
ax1.legend()
ax2.grid(True)
ax2.plot(t, theta, label=r"$\theta(t)$", color="C2")
ax2.legend()
xlabel("time")
pass

# %% [markdown]
# 🧩 Use the simulation results to display the robot location every 0.5 second.

# %%
# 🔓
t = linspace(0.0, 4.0, 4*2+1)
sol_t = r["sol"](t)
draw_arena(-4, 4, -1, 5)
for x, y, theta in sol_t.T:
    draw_wheelchair(x, y, theta)

# %% [markdown]
# 🧩 What should be the analytical expression of $x(t)$, $y(t)$ and $\theta(t)$?

# %% [markdown]
# $\theta(t) = 2 \pi / 4.0$, $x(t) = 2\sin(2\pi t / 4)$ and $y(t) = -2 \cos(2\pi t / 4)+2$.

# %% [markdown]
# 🧩 Do you experimental results match the theoretical results ? Draw the curves of the simulation error at time $t$ for $x$, $y$ and $\theta$.

# %%
t = linspace(0.0, 4.0, 1000)
x_t, y_t, theta_t = r["sol"](t)
fig=figure(figsize=(15, 15))
ax1, ax2 = fig.subplots(2, 1, sharex=True)
ax1.grid(True)
ax1.plot(t , x_t - 2*sin(2*pi*t/4), label="$x(t)$ error")
ax1.plot(t , y_t + 2*cos(2*pi*t/4) - 2, label="$y(t)$ error")
ax1.legend()
ax2.grid(True)
ax2.plot(t, theta_t - 2*pi*t / 4.0, label=r"$\theta(t)$ error")
ax2.legend()
xlabel("time")
pass

# %% [markdown]
# 🧩 If needed, adjust the simulation parameters until this error is uniformly less than $2 \times 10^{-5}$ for every component of $(x, y, \theta)$.

# %%
r = solve_ivp(
    fun=fun, 
    t_span=(0.0, 4.0), 
    y0=[0.0, 0.0, 0.0], 
    rtol=1e-6, 
    atol=1e-12, 
    dense_output=True
)
t = linspace(0.0, 4.0, 1000)
x_t, y_t, theta_t = r["sol"](t)
fig=figure(figsize=(15, 15))
ax1, ax2 = fig.subplots(2, 1, sharex=True)
ax1.grid(True)
ax1.plot(t , x_t - 2*sin(2*pi*t/4), label="$x(t)$ error")
ax1.plot(t , y_t + 2*cos(2*pi*t/4) - 2, label="$y(t)$ error")
ax1.legend()
ax2.grid(True)
ax2.plot(t, theta_t - 2*pi*t / 4.0, label=r"$\theta(t)$ error")
ax2.legend()
xlabel("time")
pass

# %% [markdown]
# Step 2 - Control Implementation
# ===============================

# %% [markdown]
# Time dependent inputs
# ---------------------

# %% [markdown]
# We are going to simulate the case of the chariot controlled by time-dependent angular velocities $\omega_l$ and $\omega_r$.
# We want a simulation lasting 5 seconds with the following inputs:
# $$
#     \omega_l(t) = \left\{
#        \begin{array}{rl}
#            (1 - L/4) \pi / R_w & \mbox{when $t \leq 1s$ or $t \geq 3$,} \\
#            (1 + L/4) \pi / R_w & \mbox{otherwise.}
#        \end{array}
#     \right.
# $$
# and
# $$
#     \omega_r(t) = \left\{
#        \begin{array}{rl}
#            (1 + L/4) \pi / R_w & \mbox{when $t \leq 1s$ or $t \geq 3$,} \\
#            (1 - L/4) \pi / R_w & \mbox{otherwise.}
#        \end{array}
#     \right.
# $$

# %% [markdown]
# ##### 🧩 Provide the new definition of `omega`

# %%
# 🔓
def omega(t, xytheta):
    if t <= 1 or t >= 3:
        omega_l = (1 - L/4) * pi / Rw
        omega_r = (1 + L/4) * pi / Rw
    else:
        omega_l = (1 + L/4) * pi / Rw
        omega_r = (1 - L/4) * pi / Rw
    return array([omega_l, omega_r])

# %% [markdown]
# ##### 🧩 Make a simulation of 4 sec of the robot with the previous input. Use the `rtol` and `atol` that used to guarantee a precision of $2 \times 10^{-5}$ and by using the `dense_output` option to evaluate the solution at timesteps that will be defined later.
#
# 🗝️ **Hint.** It is not necessary to define again the function `fun`. If the previous cell has been correctly validated, `fun` will use the new definition of `omega`.

# %%
# 🔓
tf = 4
r = solve_ivp(fun=fun,y0=[0,0,0],t_span=[0,tf], rtol=1e-6, atol=1e-12, dense_output=True)

# %% [markdown]
# 🧩 Use the simulation results to display the robot location every 0.5 seconds.

# %%
# 🔓
step = 0.5
t = arange(0,tf+step,step)
sol_t = r["sol"](t)
draw_arena(-1, 9, -1, 5)
for x, y, theta in sol_t.T:
    draw_wheelchair(x, y, theta)

# %% [markdown]
# ## Analysis of the system at rest

# %% [markdown]
# ### Equilibrium

# %% [markdown]
# ##### 🧩 Show that for a suitable (constant) choice $\omega_e \in \mathbb{R}^2$ of the vector input $\omega$, the state $X_e = (x_e, y_e, \theta_e) = (0,0,0)$ is an equilibrium of the wheelchair kinematic model.

# %% [markdown]
# 🔓 **Answer.** If $\omega_e=(0,0)$, $f(X_e)=0$ ($X_e=(0,0,0)$), and so $X_e$ is an equilibrium.

# %% [markdown]
# ##### 🧩 Show that for any other $\omega_e$, the system has no equilibrium.

# %% [markdown]
# 🔓 **Answer.** If $\omega_l\neq 0$ or $\omega_l\neq 0$, two cases:
#
#   1. $\omega_l\neq-\omega_r$ which is different from zero, thus $\dot{x}=\dot{y}=0$ implies $\cos\theta=\sin\theta=0$ which is impossible.
#   2. $\omega_l=-\omega_r$ which is different from zero, thus $\dot{\theta} = 2\omega_r\frac RD \neq 0$
#
# So, there is no equilibrium if $\omega \neq \omega_e$

# %% [markdown]
# ##### 🧩 Conversely, if $\omega = \omega_e$, what are the other equilibria of the system?

# %% [markdown]
# 🔓 **Answer.** If $\omega=\omega_e$, then $\forall X\in\mathbb{R}^3,f(X) = 0$. Every position is an equilibrium (actually, the system is at rest)

# %% [markdown]
# ### Linearized System Model
#
#
# Let $\omega = \omega_e$ and $X_e = (0,0,0)$. Let us introduce the the error variable $\Delta X = (\Delta x, \Delta y, \Delta \theta) = X - X_e$ and $\Delta \omega = \omega - \omega_e$.

# %% [markdown]
# ##### 🧩 Compute the corresponding linearized dynamics and put it in standard form: compute the matrices $A$ and $B$ (remember that $\omega = (\omega_l,\omega_r)$).

# %% [markdown]
# 🔓 **Answer.**
#
# $$
# A= \begin{bmatrix} 0 & 0 &0 \\ 0 & 0 &0 \\ 0 & 0 & 0\end{bmatrix}
# $$
# and
# $$
# B= \begin{bmatrix} \frac{R_w}{2} & \frac{R_w}{2}  \\ 0 & 0 \\ -\frac{R_w}{L} & \frac{R_w}{L} \end{bmatrix}
# $$

# %% [markdown]
# ### Stability of the linearized system

# %% [markdown]
# ##### 🧩 Is the linearized system asymptotically stable around $(0,0,0)$ when $\Delta \omega = (0,0)$ ?

# %% [markdown]
# 🔓 **Answer.** No, with the chosen $\Delta \omega$, we have $\dot X = AX$ and $A$ has three null eigenvalues. To have a positive answer, we expected each eigenvalue to have a strictly negative real part.

# %% [markdown]
# ##### 🧩 Is the original system asymptotically stable ? Or even (locally) attractive ?

# %% [markdown]
# 🔓 **Answer.** With $\omega = \omega_e$, the system cannot "move". If $X(t_0) = X_0$, then $\forall t>0, X(t) =X_0$. Thus, if $X_0\neq (0,0,0)$, $X(t)$ does not converge to the origin: the original system is not (even locally) attractive.
#
# As a consequence, it is not asymptotically stable.

# %% [markdown]
# ### Controllability of the linearized system

# %% [markdown]
# In this section, we consider only the linearized system defined by the matrices $A$ and $B$ computed previously:
#
# $$
# \frac{\Delta X}{dt} = A \Delta X + B\Delta u
# $$

# %% [markdown]
# ##### 🧩 Is there an admissible trajectory that start with the state $X_0=(-2,0,0)$ and ends at origin after some time?

# %% [markdown]
# 🔓 **Answer.** Yes, with $\omega \propto (1,1)$, the robot will move in straight line on the (Ox) axis and will reach the origin after some time depending on the speed.

# %% [markdown]
# ##### 🧩 Is there an admissible trajectory that start with the state $X_0=(0,2,0)$ and ends at origin after some time?

# %% [markdown]
# 🔓 **Answer.** No. According to $A$ and $B$, we have $d{\Delta y}/dt=0$ and so, the error on $y$ cannot be changed by $u$.

# %% [markdown]
# ##### 🧩 Is the linearized system controllable?

# %% [markdown]
# 🔓 **Answer.** No, 2 possible proofs:
#
# 1. Kalman criteria: the controllability matrix has the same rank of $B$ (since $A =0$) which is 2.
#
# 2. We found that some points are not reachable with specific initial condition.

# %% [markdown]
# ## Control on a straight line
#
# ### Admissible trajectories

# %% [markdown]
# Let $x_R(t) = v t$ and $y_R(t) = 0$ where $v \in \mathbb{R}$ and $v \neq 0$.

# %% [markdown]
# ##### 🧩 Determine the set of trajectories $X_R(t) = (x_R(t), y_R(t), \theta_R(t))$ which are admissible and compute the corresponding reference control $\omega_{R}(t)$.

# %% [markdown]
# 🔓 **Answer.** $y_R(t) = 0 \Rightarrow$ $\sin\theta_R = 0$ or $(\omega_l+\omega_r)/2 = 0$. The second case leads to $\dot{x}$=0 which is in contradiction with $\dot x_R = v$.
# Thus, $\theta_R(t) = k\pi$. By continuity ($\theta$ cannot jump from $k\pi$ to $k'\pi$), this defines several sets of solutions in which $\theta_R(t)$ is constant and equal to $k\pi$. This leads to $\dot\theta=0$ and so $\omega_l(t)=\omega_r(t)=\omega(t)$
#
# Finally, $\dot x = R_w\omega(t)\cos k\pi$.
#
# We have actually 2 true sets of solutions (all the other sets will lead to the same control according to the parity of  :
#
# 1. $X_R(t) = (vt ,0, 0)$ with a reference control $\omega_R(t)=(v/R_w,v/R_w)$
# 1. $X_R(t) = (vt ,0, \pi)$ with a reference control $\omega_R(t)=(-v/R_w,-v/R_w)$

# %% [markdown]
# ### Linearized system

# %% [markdown]
# Let $\Delta X(t) = X(t) - X_R(t)$ and $\Delta \omega(t) = \omega(t) - \omega_R(t)$.

# %% [markdown]
# ##### 🧩 Compute the linearized dynamics of the system for the class of trajectory "moving forward".

# %% [markdown]
# 🔓 **Answer.**
#
# $$
#   A = \begin{bmatrix}
#       0 & 0 & 0 \\
#       0 & 0 & v \\
#       0 & 0 & 0
#   \end{bmatrix}
# $$
#
# and
#
# $$
#    B=\begin{bmatrix}
#     \frac{R_w}{2} & \frac{R_w}{2}  \\ 0 & 0 \\ -\frac{R_w}{L} & \frac{R_w}{L}
#   \end{bmatrix}
# $$

# %% [markdown]
# ##### 🧩 Is the system asymptotically stable, with $\Delta\omega(t)=0$?

# %% [markdown]
# 🔓 **Answer.** No since $A$ has 3 null eigenvalues.

# %% [markdown]
# ##### 🧩 Is the system attractive, with $\Delta\omega(t)=0$?

# %% [markdown]
# 🔓 **Answer.** No. Two possible justifications:
# 1. With an argument of the course: for linear system, locally attractive is equivalent to GAS. The system is not GAS (pprevious question).
# 2. By looking the system: e.g. the error $\Delta x$ remains constant without any input correction.

# %% [markdown]
# ##### 🧩 Show that the linearized system is controllable.

# %% [markdown]
# 🔓 **Answer.** We just study the rank of $C' = [B, AB]$ since $A^i=0$ for $i\geq2$
#
# $$C'=
# \begin{bmatrix}
#     \frac{R_w}{2} & \frac{R_w}{2} & 0 & 0 \\
#     0 & 0 & -v \frac{R_w}{L} & v \frac{R_w}{L} \\
#     -\frac{R_w}{2} & \frac{R_w}{2} & 0 & 0
# \end{bmatrix}
# $$
#
# The submatrix defined by keeping the 3 first columns if full rank. So, the controllability matrix is also full rank and the system is controllable.

# %% [markdown]
# ### Linearized system implementation

# %% [markdown]
# In the sequel, we will use $v=4.8 \mbox{ km/h}$.

# %% [markdown]
# ##### 🧩 Implement and print the matrices $A$ and $B$

# %%
v = 4.8 / 3.6
A = array([[0, 0, 0], [0, 0, v], [0, 0, 0]])
B = array([[Rw/2, Rw/2], [0, 0], [-Rw/L, Rw/L]])
print(A)
print(B)
# Out:
# [[0.         0.         0.        ]
#  [0.         0.         1.33333333]
#  [0.         0.         0.        ]]
# [[ 0.15  0.15]
#  [ 0.    0.  ]
#  [-0.6   0.6 ]]

# %% [markdown]
# The linear model has to be fed with some $\Delta\omega$ input. Like for the nonlinear system, we define a function $\Delta\omega(t,\Delta_X)$ that computes the input of the linearized system. For example, if we do not want any correction to the reference input, we set:

# %%
def deltaOmega(t, deltaX):
    return array([0, 0, 0])

# %% [markdown]
# ##### 🧩 Using this function `deltaOmega`, define a function `lin_fun` that computes $d{\Delta X}/dt$ given the arguments `t` and `deltaX`$.

# %%
# 🔓
def lin_fun(t, deltaX):
    return A @ deltaX + B @ deltaOmega(t, deltaX)

# %% [markdown]
# ### Controller Design on the linearized system

# %% [markdown]
# ##### 🧩 Implement a process that computes a gain matrix $K$ that places the poles of the linearized system at some arbitrary location.
#
# For this question, we will chose 3 real poles close to -0.5.
#
# Then, print the poles of the closed-loop system
#
# $$
# \frac{d\Delta X}{dt}= A \Delta X + B\Delta\omega
# \; \mbox{ with } \;
# \Delta\omega = -K \Delta X.
# $$

# %%
# 🔓
poles = [-0.50, -0.51, -0.52]  # Strictly negative real part
K = place_poles(A,B,poles).gain_matrix
print(K)
e,_ = eig(A - B @ K)
print(e)
# Out:
# [[ 1.69999996 -0.16144726 -0.84727433]
#  [ 1.70000003  0.16355274  0.85272567]]
# [-0.51+0.j -0.52+0.j -0.5 +0.j]

# %% [markdown]
# ##### 🧩 Simulate the linearized system during 20s, with the initial condition $\Delta X(0) = (0,2,0)$.

# %%
def deltaOmega(t,deltaX):
    return -K @ deltaX

tf = 20
r = solve_ivp(
    fun=lin_fun, 
    t_span=[0, tf], 
    y0=[0, 2, 0], 
    dense_output=True, 
    rtol=1e-6, 
    atol=1e-12
)

# %% [markdown]
# 🧩 Plot the values of $\Delta x(t)$, $\Delta y(t)$ and $\Delta\theta(t)$ (**plot $\Delta\theta(t)$ in degrees**)

# %%
t = linspace(0.0,tf, 1000)
dx, dy, dtheta = r["sol"](t)
fig = figure(figsize=(12, 12))
ax1, ax2 = fig.subplots(2, 1, sharex=True)
ax1.grid(True)
ax1.plot(t, dx, label="$\Delta x(t)$")
ax1.plot(t, dy, label="$\Delta y(t)$")
ax1.legend()
ax2.grid(True)
ax2.plot(t, dtheta*180/pi, label=r"$\Delta\theta(t)$ deg")
ax2.legend()
None

# %% [markdown]
# ##### 🧩 Why is it important to check that $\Delta\theta(t)$ stays small ?

# %% [markdown]
# 🔓 **Answer.** The heading angle is the source of non linearity. To preserve the quality of the linearization, it is important that the error is small.

# %% [markdown]
# ##### 🧩 Compute the corresponding values of $\Delta\omega_l,\Delta\omega_r$ and store them in the Python variables `dOmega_l`, `dOmega_r`

# %%
dX = r["sol"](t)
dOmega = -K@dX
dOmega_l = dOmega[0,:]
dOmega_r = dOmega[1,:]

# %% [markdown]
# ##### 🧩 Compute $\omega_l,\omega_r$ and plot the translation speed of each wheels in km/h

# %%
omega_l = dOmega_l + v/Rw
omega_r = dOmega_r + v/Rw
fig = figure(figsize=(12, 6))
plot(t, omega_l * Rw * 3.6, label=r"Left wheel speed (km/h)")
plot(t, omega_r * Rw * 3.6, label=r"Right wheel speed (km/h)")
grid()
legend()
pass

# %% [markdown]
# ##### 🧩 Are these control values consistent with what the robot should do to cancel the error?

# %% [markdown]
# 🔓 **Answer.** If there is not any error, the target speed of both wheels is 4.8 km/h. This is the value to which $\omega_l$ and $\omega_r$ seem to converge. At the beginning, the robot is a little bit too high ($y>0$), so it has to turn right. To do this, the left wheel has to be faster than the right one. This is effectively what we observes, and both values are around 4.8 km/h.

# %% [markdown]
# ###  Controller Tuning

# %% [markdown]
# ##### 🧩 Tune the poles (and recompute the gain matrix) so that the actual location $(x, y)$ is within 10 cm of the desired location within 20 sec and the linear velocity of each wheel never exceeds $5$ km/h. Plot the values of $\Delta x$ (in m), $\Delta y$ (in m), $\Delta \theta$ (in degrees), and the speed of each wheel (in km/h)

# %%
pass

# %% [markdown]
# Step 3 - Optimal control, Global Control and General Trajectories
# =================================================================
#
#
# ###  Optimal control
#
# In this part we aim to design a stabilizing controller using an optimal control methodology.
#
# We still want to follow the reference trajectoy $x_R(t) = v t$ and $y_R(t) = 0$ where $v \in \mathbb{R}$ and $v \neq 0$ and will work with the linearized system
#
# $$
# \frac{d\Delta X}{dt}= A\Delta X + B\Delta\omega
# $$
#
# We want to find the control input $\Delta\omega$ that minimizes the quantity $J$ defined by
#
# $$
# J=\int_0^{t_f} q_1(\Delta x(t))^2 + q_2(\Delta y(t))^2 + q_3(\Delta \theta(t))^2+ r_1(\Delta \omega_l(t))^2+ r_2(\Delta \omega_r(t))^2 dt
# $$
#
# where the different constant $q_i$ and $r_i$ are strictly positive. We will denote
# $$
# Q=\begin{bmatrix}
#       q_1 & 0 & 0 \\
#       0 & q_2 & 0 \\
#       0 & 0 & q_3
#   \end{bmatrix}
# $$
# and
# $$
# R_0=\begin{bmatrix}
#       r_1 & 0 \\
#       0 & r_2 \\
#   \end{bmatrix}
# $$
#
# 🧩 Implement a function `Compute_cost` that computes the function $J$ for a given set of matrices $Q$ and $R$, a time horizon $t=[0,t_f]$, and for the corresponding functions $\Delta X$ and $\Delta \omega$ .
# To compute the integral, you can use the function `quad` (https://docs.scipy.org/doc/scipy/tutorial/integrate.html). You may need an intermediate function that returns the quantity
# $$
# q_1(\Delta x(t))^2 + q_2(\Delta y(t))^2 + q_3(\Delta \theta(t))^2+ r_1(\Delta \omega_l(t))^2+ r_2(\Delta \omega_r(t))^2
# $$

# %%
def Compute_cost(deltaX, deltaOmega):
    result = quad(lambda t :  dot(Q,deltaX(t)**2) + dot(R,deltaOmega(t)**2), 0, tf)
    return result

# %% [markdown]
# 🧩 Test the function `Compute_cost`  with the controller you designed in the Section 'Controller Tuning' when $q_i=1$ and $r_i=1$ ($t_f=20$).

# %%
Q,R = np.array([1,1,1]),np.array([1,1])
tf = 20
def deltaOmega(t,deltaX):
    return -K @ deltaX
r = solve_ivp(
    fun=lin_fun, 
    t_span=[0, tf], 
    y0=[0, 2, 0], 
    dense_output=True, 
    rtol=1e-6, 
    atol=1e-12
)
deltaX = lambda t: r["sol"](t)
deltaOmega = lambda t: -K@r["sol"](t)
print(Compute_cost(deltaX, deltaOmega))
# Out:
# (517.2822495256595, 1.2122359846079436e-06)

# %% [markdown]
# 🧩 Multiply by 10 the poles and test the function `Compute_cost` in this new case. Interpret the results.

# %%
K = place_poles(A,B,[10*x for x in poles]).gain_matrix
tf = 20
def deltaOmega(t,deltaX):
    return -K @ deltaX
r = solve_ivp(
    fun=lin_fun, 
    t_span=[0, tf], 
    y0=[0, 2, 0], 
    dense_output=True, 
    rtol=1e-6, 
    atol=1e-12
)
deltaX = lambda t: r["sol"](t)
deltaOmega = lambda t: -K@r["sol"](t)
print(Compute_cost(deltaX, deltaOmega))
# Out:
# (517.2822495256595, 1.2122359846079436e-06)

# %% [markdown]
# 🧩 Implement a process that computes a gain matrix $K$ that places the poles of the linearized system such that the quantity $J$ is minimum with "$t_f=+\infty$".
#
# Then, for $q_i=1$, $r_i=1$, print the poles of the closed-loop system:
#
# $$
# \frac{\Delta X}{dt}= A \Delta X + B\Delta\omega
# \; \mbox{ with } \;
# \Delta\omega = -K \Delta X.
# $$

# %%
tf = 1e5
iteration = 100
Poles = linspace(-5,0,iteration)
J = [0]*iteration
epsilon = 0.01
for i in range(iteration):
    poles = [Poles[i], Poles[i]-epsilon, Poles[i]-2*epsilon]  # Strictly negative real part
    K = place_poles(A,B,poles).gain_matrix
    tf = 20
    def deltaOmega(t,deltaX):
        return -K @ deltaX
    r = solve_ivp(
        fun=lin_fun, 
        t_span=[0, tf], 
        y0=[0, 2, 0], 
        dense_output=True, 
        rtol=1e-6, 
        atol=1e-12
    )
    deltaX = lambda t: r["sol"](t)
    deltaOmega = lambda t: -K@r["sol"](t)
    J[i] = Compute_cost(deltaX, deltaOmega)[0]
min_poles = Poles[argmin(J)]
poles = [min_poles, min_poles-epsilon, min_poles-2*epsilon]
print(poles)
# Out:
# [-1.1616161616161618, -1.1716161616161618, -1.1816161616161618]

# %% [markdown]
# 🧩 Plot the values of $\Delta x$ (in m), $\Delta y$ (in m), $\Delta \theta$ (in degrees), and the speed of each wheel (in km/h). Compute the value of the cost for $t_f=20$. Compare with the control law you obtained by pole assignment. Intepret the results.

# %%
tf = 20
K = place_poles(A,B,poles).gain_matrix
def deltaOmega(t,deltaX):
        return -K @ deltaX
r = solve_ivp(
        fun=lin_fun, 
        t_span=[0, tf], 
        y0=[0, 2, 0], 
        dense_output=True, 
        rtol=1e-6, 
        atol=1e-12
    )
t = linspace(0.0,tf, 1000)
dx, dy, dtheta = r["sol"](t)
fig = figure(figsize=(12, 12))
ax1, ax2 ,ax3 = fig.subplots(3, 1, sharex=True)
ax1.grid(True)
ax1.plot(t, dx, label="$\Delta x(t)$")
ax1.plot(t, dy, label="$\Delta y(t)$")
ax1.legend()
ax2.grid(True)
ax2.plot(t, dtheta*180/pi, label=r"$\Delta\theta(t)$ deg")
ax2.legend()
ax3.grid(True)
dX = r["sol"](t)
dOmega = -K@dX
dOmega_l = dOmega[0,:]
dOmega_r = dOmega[1,:]
omega_l = dOmega_l + v/Rw
omega_r = dOmega_r + v/Rw
ax3.plot(t, omega_l * Rw * 3.6, label=r"Left wheel speed (km/h)")
ax3.plot(t, omega_r * Rw * 3.6, label=r"Right wheel speed (km/h)")
ax3.legend()
print(Compute_cost(lambda t : r["sol"](t),lambda t : -K@r["sol"](t)))
# Out:
# (6.183144051879396, 7.539452299982307e-09)

# %% [markdown]
# 🧩 Try large values of $Q$ then large values of $R$ and explain how these choices influence the control effort as well as the convergence speed. Do you think that both strategies will perform similarly when applied to the wheelchair nonlinear model? Then select $Q$ and $R$ to ensure that the wheel velocity nevers exceeds 5 km/h and that $x$ and $y$ have less than 10 cm error after 20 sec.

# %%
Q,R = np.array([100,100,100]),np.array([100,100])
tf = 1e5
iteration = 100
Poles = linspace(-5,0,iteration)
J = [0]*iteration
epsilon = 0.01
for i in range(iteration):
    poles = [Poles[i], Poles[i]-epsilon, Poles[i]-2*epsilon]  # Strictly negative real part
    K = place_poles(A,B,poles).gain_matrix
    def deltaOmega(t,deltaX):
        return -K @ deltaX
    r = solve_ivp(
            fun=lin_fun, 
            t_span=[0, tf], 
            y0=[0, 2, 0], 
            dense_output=True, 
            rtol=1e-6, 
            atol=1e-12
        )
    deltaX = lambda t: r["sol"](t)
    deltaOmega = lambda t: -K@r["sol"](t)
    J[i] = Compute_cost(deltaX, deltaOmega)[0]
min_poles = Poles[argmin(J)]
poles = [min_poles, min_poles-epsilon, min_poles-2*epsilon]
tf = 20
print(Compute_cost(lambda t : r["sol"](t),lambda t : -K@r["sol"](t)))
q,r = 1, 1
Q,R = np.array([q,q,q]),np.array([r,r])
while max(omega_l * Rw * 3.6) < 5 and max(omega_r * Rw * 3.6) < 5 and max(dx)  < 0.1 and max(dy) < 0.1:
    q+= 1
    r+= 1
    Q,R = np.array([q,q,q]),np.array([r,r])
    for i in range(iteration):
        poles = [Poles[i], Poles[i]-epsilon, Poles[i]-2*epsilon]  # Strictly negative real part
        K = place_poles(A,B,poles).gain_matrix
        def deltaOmega(t,deltaX):
            return -K @ deltaX
        r = solve_ivp(
            fun=lin_fun, 
            t_span=[0, tf], 
            y0=[0, 2, 0], 
            dense_output=True, 
            rtol=1e-6, 
            atol=1e-12
        )
        deltaX = lambda t: r["sol"](t)
        deltaOmega = lambda t: -K@r["sol"](t)
        J[i] = Compute_cost(deltaX, deltaOmega)[0]
    min_poles = Poles[argmin(J)]
    poles = [min_poles, min_poles-epsilon, min_poles-2*epsilon]
    K = place_poles(A,B,poles).gain_matrix
    dx, dy, dtheta = r["sol"](t)
    dX = r["sol"](t)
    dOmega = -K@dX
    dOmega_l = dOmega[0,:]
    dOmega_r = dOmega[1,:]
    omega_l = dOmega_l + v/Rw
    omega_r = dOmega_r + v/Rw
print(omega_l * Rw * 3.6,omega_r * Rw * 3.6,dx,dy)
# Out:
# (8000.000111043508, 8.881784320284312e-11)
# [6.64401387 6.55901351 6.47696329 6.39777209 6.32135142 6.24761545
#  6.17648075 6.10786631 6.04169345 5.9778859  5.91636962 5.85707261
#  5.79992501 5.74485896 5.6918087  5.64071046 5.59150224 5.5441238
#  5.49851671 5.45462425 5.41239151 5.37176521 5.33269355 5.29512622
#  5.25901443 5.22431082 5.19096956 5.15894623 5.12819767 5.09868194
#  5.07035834 5.04318741 5.0171309  4.99215185 4.96821436 4.94528357
#  4.92332561 4.90230766 4.88219789 4.86296545 4.84458058 4.82701437
#  4.81023876 4.79422648 4.77895111 4.76438705 4.75050948 4.73729448
#  4.72471886 4.71276009 4.70139631 4.69060631 4.68036957 4.67066618
#  4.66147691 4.65278324 4.64456716 4.63681121 4.62949844 4.62261244
#  4.6161373  4.61005765 4.60435864 4.59902597 4.59404575 4.58940451
#  4.58508918 4.58108712 4.57738608 4.57397422 4.57084014 4.56797285
#  4.5653617  4.56299636 4.56086684 4.55896343 4.55727678 4.55579782
#  4.55451782 4.55342837 4.55252139 4.55178902 4.55122365 4.55081791
#  4.55056468 4.55045709 4.5504885  4.55065249 4.55094297 4.551354
#  4.55187987 4.55251501 4.55325407 4.55409187 4.55502341 4.55604388
#  4.55714864 4.55833326 4.55959349 4.56092519 4.56232438 4.5637872
#  4.56530994 4.566889   4.56852095 4.57020247 4.57193039 4.5737017
#  4.57551348 4.57736289 4.57924722 4.58116385 4.58311024 4.58508398
#  4.58708275 4.58910429 4.59114652 4.5932074  4.59528499 4.59737741
#  4.59948285 4.60159957 4.60372591 4.60586027 4.60800113 4.61014703
#  4.6122966  4.61444853 4.61660158 4.61875455 4.62090626 4.62305563
#  4.62520159 4.62734313 4.62947931 4.6316092  4.63373196 4.63584678
#  4.63795292 4.64004964 4.64213624 4.64421207 4.6462765  4.64832893
#  4.6503688  4.65239559 4.6544088  4.65640797 4.65839269 4.66036257
#  4.66231722 4.6642563  4.66617948 4.66808645 4.66997691 4.67185061
#  4.6737073  4.67554676 4.67736878 4.6791732  4.68095987 4.68272864
#  4.68447938 4.68621198 4.68792634 4.68962237 4.69129999 4.69295913
#  4.69459976 4.69622182 4.69782531 4.69941023 4.70097657 4.70252435
#  4.7040536  4.70556433 4.70705658 4.7085304  4.70998584 4.71142294
#  4.71284178 4.71424243 4.71562496 4.71698947 4.71833606 4.71966484
#  4.72097589 4.72226934 4.72354529 4.72480386 4.72604516 4.72726933
#  4.72847647 4.72966672 4.73084022 4.73199709 4.73313749 4.73426156
#  4.73536944 4.73646129 4.73753726 4.73859749 4.73964213 4.74067134
#  4.74168527 4.74268407 4.74366789 4.7446369  4.74559124 4.74653108
#  4.74745659 4.74836791 4.74926522 4.75014867 4.75101843 4.75187466
#  4.75271752 4.75354717 4.75436376 4.75516745 4.75595841 4.75673678
#  4.75750273 4.7582564  4.75899797 4.75972758 4.7604454  4.76115158
#  4.76184628 4.76252964 4.76320183 4.76386299 4.76451328 4.76515284
#  4.76578181 4.76640035 4.7670086  4.76760671 4.7681948  4.76877304
#  4.76934156 4.76990049 4.77044999 4.77099018 4.77152121 4.77204321
#  4.77255631 4.77306065 4.77355635 4.77404355 4.77452237 4.77499294
#  4.77545538 4.77590982 4.77635638 4.77679518 4.77722633 4.77764997
#  4.77806621 4.77847515 4.77887692 4.77927164 4.7796594  4.78004032
#  4.78041452 4.78078209 4.78114314 4.78149778 4.78184611 4.78218824
#  4.78252425 4.78285426 4.78317836 4.78349665 4.78380922 4.78411616
#  4.78441758 4.78471355 4.78500418 4.78528955 4.78556974 4.78584485
#  4.78611496 4.78638015 4.78664051 4.78689611 4.78714704 4.78739339
#  4.78763521 4.7878726  4.78810563 4.78833437 4.78855889 4.78877928
#  4.78899559 4.78920791 4.78941629 4.78962082 4.78982155 4.79001855
#  4.79021188 4.79040162 4.79058781 4.79077054 4.79094985 4.7911258
#  4.79129846 4.79146789 4.79163413 4.79179725 4.79195731 4.79211435
#  4.79226843 4.79241961 4.79256793 4.79271345 4.79285622 4.79299628
#  4.79313369 4.79326849 4.79340073 4.79353045 4.79365771 4.79378254
#  4.793905   4.79402512 4.79414294 4.79425851 4.79437188 4.79448307
#  4.79459213 4.79469909 4.79480401 4.79490691 4.79500783 4.79510681
#  4.79520388 4.79529908 4.79539244 4.795484   4.7955738  4.79566185
#  4.7957482  4.79583288 4.79591592 4.79599735 4.7960772  4.79615549
#  4.79623227 4.79630755 4.79638136 4.79645374 4.7965247  4.79659428
#  4.7966625  4.79672939 4.79679498 4.79685927 4.79692231 4.79698412
#  4.79704471 4.79710412 4.79716235 4.79721945 4.79727542 4.79733029
#  4.79738408 4.79743681 4.79748851 4.79753918 4.79758885 4.79763755
#  4.79768528 4.79773206 4.79777793 4.79782288 4.79786695 4.79791014
#  4.79795247 4.79799397 4.79803464 4.7980745  4.79811357 4.79815187
#  4.7981894  4.79822619 4.79826224 4.79829758 4.79833221 4.79836615
#  4.79839941 4.79843201 4.79846395 4.79849526 4.79852595 4.79855601
#  4.79858548 4.79861436 4.79864265 4.79867038 4.79869756 4.79872419
#  4.79875028 4.79877585 4.7988009  4.79882546 4.79884951 4.79887309
#  4.79889619 4.79891882 4.798941   4.79896273 4.79898402 4.79900488
#  4.79902532 4.79904535 4.79906497 4.7990842  4.79910303 4.79912149
#  4.79913957 4.79915729 4.79917464 4.79919165 4.79920831 4.79922463
#  4.79924062 4.79925629 4.79927164 4.79928667 4.7993014  4.79931583
#  4.79932997 4.79934382 4.79935739 4.79937068 4.7993837  4.79939645
#  4.79940894 4.79942118 4.79943317 4.79944492 4.79945642 4.79946769
#  4.79947873 4.79948954 4.79950014 4.79951051 4.79952067 4.79953063
#  4.79954038 4.79954993 4.79955928 4.79956845 4.79957742 4.79958621
#  4.79959482 4.79960326 4.79961152 4.79961961 4.79962753 4.79963529
#  4.79964289 4.79965034 4.79965763 4.79966477 4.79967177 4.79967862
#  4.79968533 4.7996919  4.79969833 4.79970464 4.79971081 4.79971685
#  4.79972277 4.79972857 4.79973425 4.79973981 4.79974525 4.79975059
#  4.79975581 4.79976092 4.79976593 4.79977084 4.79977564 4.79978034
#  4.79978495 4.79978946 4.79979388 4.7997982  4.79980244 4.79980658
#  4.79981065 4.79981462 4.79981852 4.79982233 4.79982607 4.79982972
#  4.7998333  4.79983681 4.79984024 4.7998436  4.79984689 4.79985012
#  4.79985327 4.79985636 4.79985939 4.79986235 4.79986525 4.79986809
#  4.79987087 4.7998736  4.79987626 4.79987887 4.79988143 4.79988393
#  4.79988638 4.79988878 4.79989113 4.79989343 4.79989568 4.79989788
#  4.79990004 4.79990216 4.79990422 4.79990625 4.79990823 4.79991017
#  4.79991207 4.79991394 4.79991576 4.79991754 4.79991929 4.799921
#  4.79992267 4.79992431 4.79992591 4.79992748 4.79992902 4.79993053
#  4.799932   4.79993344 4.79993485 4.79993624 4.79993759 4.79993891
#  4.79994021 4.79994148 4.79994272 4.79994394 4.79994513 4.7999463
#  4.79994744 4.79994856 4.79994965 4.79995072 4.79995177 4.7999528
#  4.7999538  4.79995478 4.79995575 4.79995669 4.79995761 4.79995851
#  4.7999594  4.79996026 4.79996111 4.79996194 4.79996275 4.79996354
#  4.79996432 4.79996508 4.79996582 4.79996655 4.79996727 4.79996797
#  4.79996865 4.79996932 4.79996997 4.79997061 4.79997124 4.79997186
#  4.79997246 4.79997305 4.79997362 4.79997419 4.79997474 4.79997528
#  4.79997581 4.79997632 4.79997683 4.79997733 4.79997781 4.79997829
#  4.79997875 4.79997921 4.79997965 4.79998009 4.79998051 4.79998093
#  4.79998134 4.79998174 4.79998213 4.79998251 4.79998289 4.79998325
#  4.79998361 4.79998396 4.79998431 4.79998464 4.79998497 4.7999853
#  4.79998561 4.79998592 4.79998622 4.79998652 4.79998681 4.79998709
#  4.79998737 4.79998764 4.79998791 4.79998817 4.79998842 4.79998867
#  4.79998891 4.79998915 4.79998938 4.79998961 4.79998984 4.79999005
#  4.79999027 4.79999048 4.79999068 4.79999088 4.79999108 4.79999127
#  4.79999146 4.79999164 4.79999182 4.799992   4.79999217 4.79999234
#  4.7999925  4.79999267 4.79999282 4.79999298 4.79999313 4.79999328
#  4.79999342 4.79999356 4.7999937  4.79999384 4.79999397 4.7999941
#  4.79999423 4.79999435 4.79999448 4.7999946  4.79999471 4.79999483
#  4.79999494 4.79999505 4.79999515 4.79999526 4.79999536 4.79999546
#  4.79999556 4.79999566 4.79999575 4.79999584 4.79999593 4.79999602
#  4.7999961  4.79999619 4.79999627 4.79999635 4.79999643 4.79999651
#  4.79999658 4.79999666 4.79999673 4.7999968  4.79999687 4.79999694
#  4.799997   4.79999707 4.79999713 4.79999719 4.79999726 4.79999731
#  4.79999737 4.79999743 4.79999749 4.79999754 4.79999759 4.79999765
#  4.7999977  4.79999775 4.7999978  4.79999784 4.79999789 4.79999794
#  4.79999798 4.79999802 4.79999807 4.79999811 4.79999815 4.79999819
#  4.79999823 4.79999827 4.79999831 4.79999834 4.79999838 4.79999841
#  4.79999845 4.79999848 4.79999851 4.79999855 4.79999858 4.79999861
#  4.79999864 4.79999867 4.7999987  4.79999873 4.79999875 4.79999878
#  4.79999881 4.79999883 4.79999886 4.79999888 4.79999891 4.79999893
#  4.79999896 4.79999898 4.799999   4.79999902 4.79999904 4.79999906
#  4.79999908 4.7999991  4.79999912 4.79999914 4.79999916 4.79999918
#  4.7999992  4.79999922 4.79999923 4.79999925 4.79999927 4.79999928
#  4.7999993  4.79999931 4.79999933 4.79999934 4.79999936 4.79999937
#  4.79999938 4.7999994  4.79999941 4.79999942 4.79999944 4.79999945
#  4.79999946 4.79999947 4.79999948 4.79999949 4.79999951 4.79999952
#  4.79999953 4.79999954 4.79999955 4.79999956 4.79999957 4.79999958
#  4.79999959 4.79999959 4.7999996  4.79999961 4.79999962 4.79999963
#  4.79999964 4.79999965 4.79999965 4.79999966 4.79999967 4.79999968
#  4.79999968 4.79999969 4.7999997  4.7999997  4.79999971 4.79999972
#  4.79999972 4.79999973 4.79999973 4.79999974 4.79999975 4.79999975
#  4.79999976 4.79999976 4.79999977 4.79999977 4.79999978 4.79999978
#  4.79999979 4.79999979 4.7999998  4.7999998  4.7999998  4.79999981
#  4.79999981 4.79999982 4.79999982 4.79999983 4.79999983 4.79999983
#  4.79999984 4.79999984 4.79999984 4.79999985 4.79999985 4.79999985
#  4.79999986 4.79999986 4.79999986 4.79999987 4.79999987 4.79999987
#  4.79999987 4.79999988 4.79999988 4.79999988 4.79999989 4.79999989
#  4.79999989 4.79999989 4.7999999  4.7999999  4.7999999  4.7999999
#  4.7999999  4.79999991 4.79999991 4.79999991 4.79999991 4.79999991
#  4.79999992 4.79999992 4.79999992 4.79999992 4.79999992 4.79999992
#  4.79999993 4.79999993 4.79999993 4.79999993 4.79999993 4.79999993
#  4.79999994 4.79999994 4.79999994 4.79999994 4.79999994 4.79999994
#  4.79999994 4.79999994 4.79999995 4.79999995 4.79999995 4.79999995
#  4.79999995 4.79999995 4.79999995 4.79999995 4.79999995 4.79999996
#  4.79999996 4.79999996 4.79999996 4.79999996 4.79999996 4.79999996
#  4.79999996 4.79999996 4.79999996 4.79999996 4.79999997 4.79999997
#  4.79999997 4.79999997 4.79999997 4.79999997 4.79999997 4.79999997
#  4.79999997 4.79999997 4.79999997 4.79999997 4.79999997 4.79999997
#  4.79999997 4.79999998 4.79999998 4.79999998 4.79999998 4.79999998
#  4.79999998 4.79999998 4.79999998 4.79999998 4.79999998 4.79999998
#  4.79999998 4.79999998 4.79999998 4.79999998 4.79999998 4.79999998
#  4.79999998 4.79999998 4.79999998 4.79999998 4.79999998 4.79999998
#  4.79999999 4.79999999 4.79999999 4.79999999 4.79999999 4.79999999
#  4.79999999 4.79999999 4.79999999 4.79999999 4.79999999 4.79999999
#  4.79999999 4.79999999 4.79999999 4.79999999 4.79999999 4.79999999
#  4.79999999 4.79999999 4.79999999 4.79999999 4.79999999 4.79999999
#  4.79999999 4.79999999 4.79999999 4.79999999 4.79999999 4.79999999
#  4.79999999 4.79999999 4.79999999 4.79999999 4.79999999 4.79999999
#  4.79999999 4.79999999 4.79999999 4.79999999 4.79999999 4.79999999
#  4.79999999 4.79999999 4.79999999 4.79999999 4.79999999 4.79999999
#  4.79999999 4.8        4.8        4.8        4.8        4.8
#  4.8        4.8        4.8        4.8        4.8        4.8
#  4.8        4.8        4.8        4.8        4.8        4.8
#  4.8        4.8        4.8        4.8        4.8        4.8
#  4.8        4.8        4.8        4.8       ] [2.9380359  3.02386193 3.10670923 3.18666978 3.26383295 3.3382854
#  3.41011135 3.4793926  3.5462086  3.61063634 3.67275061 3.73262406
#  3.79032727 3.84592873 3.89949485 3.95109001 4.00077681 4.04861607
#  4.0946668  4.13898626 4.18162989 4.22265149 4.26210336 4.30003628
#  4.33649955 4.37154096 4.40520679 4.43754189 4.46858984 4.498393
#  4.52699244 4.55442801 4.58073834 4.60596075 4.63013147 4.65328572
#  4.67545767 4.69668048 4.71698629 4.73640624 4.75497038 4.77270789
#  4.78964713 4.80581561 4.82124002 4.8359462  4.84995921 4.8633032
#  4.8760016  4.88807714 4.89955191 4.91044731 4.92078408 4.9305823
#  4.93986139 4.94864006 4.95693649 4.96476831 4.97215263 4.97910604
#  4.98564457 4.99178377 4.99753862 5.00292356 5.00795261 5.01263939
#  5.01699707 5.02103844 5.02477585 5.02822125 5.03138617 5.0342817
#  5.03691859 5.03930727 5.04145783 5.04338007 5.04508345 5.04657709
#  5.04786985 5.04897018 5.04988627 5.05062605 5.05119719 5.05160714
#  5.05186308 5.05197197 5.05194051 5.05177515 5.05148208 5.05106727
#  5.05053651 5.0498954  5.04914935 5.0483036  5.04736319 5.04633298
#  5.04521766 5.04402169 5.04274937 5.04140488 5.03999223 5.03851533
#  5.03697793 5.03538365 5.03373596 5.03203821 5.0302936  5.02850518
#  5.0266759  5.0248086  5.02290605 5.02097087 5.01900564 5.01701279
#  5.01499467 5.01295354 5.01089153 5.00881067 5.00671293 5.00460023
#  5.00247437 5.00033711 4.99819014 4.99603506 4.99387342 4.9917067
#  4.98953626 4.98736342 4.98518946 4.98301558 4.98084296 4.97867271
#  4.9765059  4.97434353 4.97218659 4.97003599 4.9678926  4.9657572
#  4.96363058 4.96151347 4.95940657 4.95731055 4.95522603 4.95315363
#  4.9510939  4.94904738 4.94701458 4.94499595 4.9429919  4.94100285
#  4.93902916 4.93707119 4.93512928 4.93320374 4.93129486 4.9294029
#  4.92752812 4.92567074 4.92383097 4.92200896 4.92020488 4.91841887
#  4.91665105 4.91490156 4.91317049 4.91145792 4.90976395 4.90808862
#  4.90643199 4.90479411 4.90317497 4.9015746  4.89999298 4.89843009
#  4.89688593 4.89536045 4.89385363 4.89236543 4.89089579 4.88944466
#  4.88801197 4.88659765 4.88520162 4.88382378 4.88246404 4.8811223
#  4.87979844 4.87849236 4.87720394 4.87593308 4.87467965 4.87344353
#  4.87222459 4.87102271 4.86983775 4.86866957 4.86751803 4.86638298
#  4.86526426 4.86416174 4.86307526 4.86200467 4.86094981 4.85991054
#  4.8588867  4.85787813 4.85688468 4.8559062  4.85494252 4.85399349
#  4.85305894 4.8521387  4.85123261 4.85034052 4.84946224 4.84859764
#  4.84774653 4.84690877 4.84608419 4.84527263 4.84447393 4.84368794
#  4.84291449 4.84215344 4.84140461 4.84066786 4.83994301 4.83922992
#  4.83852842 4.83783836 4.83715959 4.83649195 4.8358353  4.83518948
#  4.83455434 4.83392974 4.83331553 4.83271157 4.83211771 4.83153381
#  4.83095972 4.83039531 4.82984043 4.82929494 4.8287587  4.82823159
#  4.82771346 4.82720418 4.82670361 4.82621164 4.82572812 4.82525294
#  4.82478597 4.82432707 4.82387613 4.82343303 4.82299765 4.82256986
#  4.82214954 4.82173658 4.82133087 4.82093228 4.82054072 4.82015605
#  4.81977819 4.81940701 4.81904241 4.81868429 4.81833254 4.81798706
#  4.81764775 4.8173145  4.81698722 4.81666581 4.81635017 4.81604021
#  4.81573584 4.81543696 4.81514347 4.81485531 4.81457236 4.81429455
#  4.81402179 4.81375399 4.81349108 4.81323296 4.81297956 4.8127308
#  4.8124866  4.81224688 4.81201156 4.81178057 4.81155384 4.81133129
#  4.81111285 4.81089845 4.81068801 4.81048148 4.81027878 4.81007984
#  4.80988461 4.809693   4.80950498 4.80932046 4.80913938 4.8089617
#  4.80878734 4.80861625 4.80844837 4.80828364 4.80812201 4.80796343
#  4.80780783 4.80765516 4.80750538 4.80735843 4.80721426 4.80707282
#  4.80693406 4.80679793 4.80666439 4.80653339 4.80640488 4.80627882
#  4.80615516 4.80603385 4.80591487 4.80579816 4.80568368 4.8055714
#  4.80546126 4.80535324 4.8052473  4.80514338 4.80504147 4.80494151
#  4.80484349 4.80474735 4.80465306 4.8045606  4.80446992 4.804381
#  4.8042938  4.80420828 4.80412443 4.8040422  4.80396156 4.8038825
#  4.80380497 4.80372894 4.8036544  4.80358131 4.80350965 4.80343938
#  4.80337049 4.80330294 4.80323671 4.80317178 4.80310811 4.8030457
#  4.80298451 4.80292452 4.80286571 4.80280805 4.80275153 4.80269611
#  4.80264179 4.80258854 4.80253634 4.80248516 4.802435   4.80238583
#  4.80233762 4.80229037 4.80224406 4.80219866 4.80215416 4.80211055
#  4.80206779 4.80202589 4.80198481 4.80194456 4.8019051  4.80186643
#  4.80182852 4.80179137 4.80175496 4.80171928 4.80168431 4.80165003
#  4.80161644 4.80158352 4.80155126 4.80151964 4.80148865 4.80145829
#  4.80142853 4.80139937 4.80137079 4.80134279 4.80131535 4.80128846
#  4.8012621  4.80123628 4.80121098 4.80118618 4.80116189 4.80113808
#  4.80111475 4.8010919  4.8010695  4.80104756 4.80102605 4.80100499
#  4.80098434 4.80096412 4.8009443  4.80092488 4.80090586 4.80088722
#  4.80086896 4.80085107 4.80083354 4.80081637 4.80079954 4.80078306
#  4.80076691 4.80075109 4.80073559 4.80072041 4.80070553 4.80069096
#  4.80067668 4.80066269 4.80064899 4.80063557 4.80062242 4.80060954
#  4.80059692 4.80058456 4.80057246 4.80056059 4.80054898 4.80053759
#  4.80052645 4.80051553 4.80050483 4.80049435 4.80048409 4.80047403
#  4.80046419 4.80045454 4.80044509 4.80043584 4.80042678 4.8004179
#  4.8004092  4.80040068 4.80039234 4.80038417 4.80037617 4.80036833
#  4.80036065 4.80035314 4.80034577 4.80033856 4.80033149 4.80032458
#  4.8003178  4.80031117 4.80030467 4.8002983  4.80029207 4.80028596
#  4.80027998 4.80027413 4.8002684  4.80026278 4.80025728 4.80025189
#  4.80024662 4.80024146 4.8002364  4.80023144 4.80022659 4.80022184
#  4.80021719 4.80021264 4.80020817 4.80020381 4.80019953 4.80019534
#  4.80019124 4.80018722 4.80018329 4.80017944 4.80017567 4.80017197
#  4.80016836 4.80016482 4.80016135 4.80015795 4.80015463 4.80015138
#  4.80014819 4.80014507 4.80014201 4.80013902 4.80013609 4.80013322
#  4.80013041 4.80012766 4.80012497 4.80012233 4.80011975 4.80011723
#  4.80011475 4.80011233 4.80010996 4.80010763 4.80010536 4.80010313
#  4.80010095 4.80009882 4.80009673 4.80009469 4.80009268 4.80009072
#  4.8000888  4.80008692 4.80008508 4.80008328 4.80008152 4.80007979
#  4.8000781  4.80007645 4.80007483 4.80007324 4.80007169 4.80007017
#  4.80006868 4.80006722 4.8000658  4.8000644  4.80006303 4.8000617
#  4.80006039 4.8000591  4.80005785 4.80005662 4.80005542 4.80005424
#  4.80005309 4.80005196 4.80005085 4.80004977 4.80004871 4.80004768
#  4.80004666 4.80004567 4.8000447  4.80004375 4.80004281 4.8000419
#  4.80004101 4.80004014 4.80003928 4.80003844 4.80003762 4.80003682
#  4.80003604 4.80003527 4.80003452 4.80003378 4.80003306 4.80003235
#  4.80003166 4.80003099 4.80003033 4.80002968 4.80002905 4.80002842
#  4.80002782 4.80002722 4.80002664 4.80002607 4.80002552 4.80002497
#  4.80002444 4.80002391 4.8000234  4.8000229  4.80002241 4.80002193
#  4.80002146 4.800021   4.80002055 4.80002011 4.80001968 4.80001926
#  4.80001885 4.80001844 4.80001805 4.80001766 4.80001728 4.80001691
#  4.80001655 4.8000162  4.80001585 4.80001551 4.80001518 4.80001485
#  4.80001453 4.80001422 4.80001392 4.80001362 4.80001332 4.80001304
#  4.80001276 4.80001248 4.80001222 4.80001195 4.8000117  4.80001145
#  4.8000112  4.80001096 4.80001072 4.80001049 4.80001027 4.80001005
#  4.80000983 4.80000962 4.80000941 4.80000921 4.80000901 4.80000882
#  4.80000863 4.80000844 4.80000826 4.80000808 4.80000791 4.80000774
#  4.80000757 4.80000741 4.80000725 4.80000709 4.80000694 4.80000679
#  4.80000664 4.8000065  4.80000636 4.80000622 4.80000609 4.80000596
#  4.80000583 4.8000057  4.80000558 4.80000546 4.80000534 4.80000523
#  4.80000511 4.800005   4.80000489 4.80000479 4.80000469 4.80000458
#  4.80000449 4.80000439 4.80000429 4.8000042  4.80000411 4.80000402
#  4.80000393 4.80000385 4.80000377 4.80000368 4.8000036  4.80000353
#  4.80000345 4.80000338 4.8000033  4.80000323 4.80000316 4.80000309
#  4.80000303 4.80000296 4.8000029  4.80000283 4.80000277 4.80000271
#  4.80000265 4.8000026  4.80000254 4.80000248 4.80000243 4.80000238
#  4.80000233 4.80000228 4.80000223 4.80000218 4.80000213 4.80000209
#  4.80000204 4.800002   4.80000195 4.80000191 4.80000187 4.80000183
#  4.80000179 4.80000175 4.80000171 4.80000167 4.80000164 4.8000016
#  4.80000157 4.80000153 4.8000015  4.80000147 4.80000144 4.8000014
#  4.80000137 4.80000134 4.80000131 4.80000129 4.80000126 4.80000123
#  4.8000012  4.80000118 4.80000115 4.80000113 4.8000011  4.80000108
#  4.80000106 4.80000103 4.80000101 4.80000099 4.80000097 4.80000095
#  4.80000092 4.8000009  4.80000089 4.80000087 4.80000085 4.80000083
#  4.80000081 4.80000079 4.80000078 4.80000076 4.80000074 4.80000073
#  4.80000071 4.80000069 4.80000068 4.80000066 4.80000065 4.80000064
#  4.80000062 4.80000061 4.8000006  4.80000058 4.80000057 4.80000056
#  4.80000055 4.80000053 4.80000052 4.80000051 4.8000005  4.80000049
#  4.80000048 4.80000047 4.80000046 4.80000045 4.80000044 4.80000043
#  4.80000042 4.80000041 4.8000004  4.80000039 4.80000038 4.80000037
#  4.80000037 4.80000036 4.80000035 4.80000034 4.80000034 4.80000033
#  4.80000032 4.80000031 4.80000031 4.8000003  4.80000029 4.80000029
#  4.80000028 4.80000027 4.80000027 4.80000026 4.80000026 4.80000025
#  4.80000025 4.80000024 4.80000024 4.80000023 4.80000023 4.80000022
#  4.80000022 4.80000021 4.80000021 4.8000002  4.8000002  4.80000019
#  4.80000019 4.80000018 4.80000018 4.80000018 4.80000017 4.80000017
#  4.80000017 4.80000016 4.80000016 4.80000015 4.80000015 4.80000015
#  4.80000014 4.80000014 4.80000014 4.80000014 4.80000013 4.80000013
#  4.80000013 4.80000012 4.80000012 4.80000012 4.80000012 4.80000011
#  4.80000011 4.80000011 4.80000011 4.8000001  4.8000001  4.8000001
#  4.8000001  4.80000009 4.80000009 4.80000009 4.80000009 4.80000009
#  4.80000008 4.80000008 4.80000008 4.80000008 4.80000008 4.80000008
#  4.80000007 4.80000007 4.80000007 4.80000007 4.80000007 4.80000007
#  4.80000007 4.80000006 4.80000006 4.80000006 4.80000006 4.80000006
#  4.80000006 4.80000006 4.80000005 4.80000005 4.80000005 4.80000005
#  4.80000005 4.80000005 4.80000005 4.80000005 4.80000005 4.80000004
#  4.80000004 4.80000004 4.80000004 4.80000004 4.80000004 4.80000004
#  4.80000004 4.80000004 4.80000004 4.80000004 4.80000003 4.80000003
#  4.80000003 4.80000003 4.80000003 4.80000003 4.80000003 4.80000003
#  4.80000003 4.80000003 4.80000003 4.80000003 4.80000003 4.80000003
#  4.80000003 4.80000002 4.80000002 4.80000002 4.80000002 4.80000002
#  4.80000002 4.80000002 4.80000002 4.80000002 4.80000002 4.80000002
#  4.80000002 4.80000002 4.80000002 4.80000002 4.80000002 4.80000002
#  4.80000002 4.80000002 4.80000002 4.80000002 4.80000002 4.80000002
#  4.80000001 4.80000001 4.80000001 4.80000001 4.80000001 4.80000001
#  4.80000001 4.80000001 4.80000001 4.80000001 4.80000001 4.80000001
#  4.80000001 4.80000001 4.80000001 4.80000001 4.80000001 4.80000001
#  4.80000001 4.80000001 4.80000001 4.80000001 4.80000001 4.80000001
#  4.80000001 4.80000001 4.80000001 4.80000001 4.80000001 4.80000001
#  4.80000001 4.80000001 4.80000001 4.80000001 4.80000001 4.80000001
#  4.80000001 4.80000001 4.80000001 4.80000001 4.80000001 4.80000001
#  4.80000001 4.80000001 4.80000001 4.80000001 4.80000001 4.80000001
#  4.80000001 4.80000001 4.8        4.8        4.8        4.8
#  4.8        4.8        4.8        4.8        4.8        4.8
#  4.8        4.8        4.8        4.8        4.8        4.8
#  4.8        4.8        4.8        4.8        4.8        4.8
#  4.8        4.8        4.8        4.8       ] [ 0.00000000e+00 -4.87570196e-05 -9.52581796e-05 -1.39581768e-04
#  -1.81803671e-04 -2.21997358e-04 -2.60234077e-04 -2.96582898e-04
#  -3.31110751e-04 -3.63882376e-04 -3.94960502e-04 -4.24405972e-04
#  -4.52277740e-04 -4.78632910e-04 -5.03526692e-04 -5.27012511e-04
#  -5.49142194e-04 -5.69965963e-04 -5.89532445e-04 -6.07888721e-04
#  -6.25080222e-04 -6.41150947e-04 -6.56143558e-04 -6.70099386e-04
#  -6.83058427e-04 -6.95059384e-04 -7.06139595e-04 -7.16335144e-04
#  -7.25681019e-04 -7.34211111e-04 -7.41958216e-04 -7.48954040e-04
#  -7.55229232e-04 -7.60813287e-04 -7.65734764e-04 -7.70021332e-04
#  -7.73699773e-04 -7.76795978e-04 -7.79334959e-04 -7.81340865e-04
#  -7.82836904e-04 -7.83845537e-04 -7.84388515e-04 -7.84486876e-04
#  -7.84160943e-04 -7.83430333e-04 -7.82313986e-04 -7.80830064e-04
#  -7.78996107e-04 -7.76829087e-04 -7.74345416e-04 -7.71560942e-04
#  -7.68490949e-04 -7.65150173e-04 -7.61552786e-04 -7.57712367e-04
#  -7.53642044e-04 -7.49354510e-04 -7.44862015e-04 -7.40176370e-04
#  -7.35308949e-04 -7.30270704e-04 -7.25072128e-04 -7.19723264e-04
#  -7.14233816e-04 -7.08613150e-04 -7.02870294e-04 -6.97013939e-04
#  -6.91052438e-04 -6.84993819e-04 -6.78845768e-04 -6.72615600e-04
#  -6.66310372e-04 -6.59936881e-04 -6.53501674e-04 -6.47011040e-04
#  -6.40471012e-04 -6.33887371e-04 -6.27265662e-04 -6.20611128e-04
#  -6.13928787e-04 -6.07223469e-04 -6.00499815e-04 -5.93762275e-04
#  -5.87015111e-04 -5.80262396e-04 -5.73508016e-04 -5.66755676e-04
#  -5.60008855e-04 -5.53270877e-04 -5.46544931e-04 -5.39834070e-04
#  -5.33141207e-04 -5.26469118e-04 -5.19820441e-04 -5.13197680e-04
#  -5.06603209e-04 -5.00039227e-04 -4.93507826e-04 -4.87010998e-04
#  -4.80550639e-04 -4.74128546e-04 -4.67746419e-04 -4.61405862e-04
#  -4.55108380e-04 -4.48855389e-04 -4.42648186e-04 -4.36487971e-04
#  -4.30375875e-04 -4.24312964e-04 -4.18300237e-04 -4.12338625e-04
#  -4.06428993e-04 -4.00572138e-04 -3.94768791e-04 -3.89019623e-04
#  -3.83325211e-04 -3.77686078e-04 -3.72102704e-04 -3.66575524e-04
#  -3.61104929e-04 -3.55691266e-04 -3.50334838e-04 -3.45035905e-04
#  -3.39794681e-04 -3.34611340e-04 -3.29485995e-04 -3.24418718e-04
#  -3.19409557e-04 -3.14458533e-04 -3.09565636e-04 -3.04730833e-04
#  -2.99954060e-04 -2.95235229e-04 -2.90574222e-04 -2.85970897e-04
#  -2.81425075e-04 -2.76936545e-04 -2.72505079e-04 -2.68130434e-04
#  -2.63812352e-04 -2.59550558e-04 -2.55344765e-04 -2.51194667e-04
#  -2.47099945e-04 -2.43060263e-04 -2.39075272e-04 -2.35144596e-04
#  -2.31267845e-04 -2.27444619e-04 -2.23674515e-04 -2.19957120e-04
#  -2.16292013e-04 -2.12678769e-04 -2.09116953e-04 -2.05606124e-04
#  -2.02145835e-04 -1.98735630e-04 -1.95375041e-04 -1.92063589e-04
#  -1.88800795e-04 -1.85586174e-04 -1.82419243e-04 -1.79299516e-04
#  -1.76226505e-04 -1.73199722e-04 -1.70218676e-04 -1.67282873e-04
#  -1.64391819e-04 -1.61545019e-04 -1.58741967e-04 -1.55982157e-04
#  -1.53265085e-04 -1.50590248e-04 -1.47957145e-04 -1.45365277e-04
#  -1.42814145e-04 -1.40303255e-04 -1.37832111e-04 -1.35400222e-04
#  -1.33007096e-04 -1.30652244e-04 -1.28335175e-04 -1.26055395e-04
#  -1.23812418e-04 -1.21605757e-04 -1.19434933e-04 -1.17299466e-04
#  -1.15198884e-04 -1.13132716e-04 -1.11100495e-04 -1.09101757e-04
#  -1.07136044e-04 -1.05202899e-04 -1.03301869e-04 -1.01432501e-04
#  -9.95943456e-05 -9.77869565e-05 -9.60098926e-05 -9.42627170e-05
#  -9.25449973e-05 -9.08563054e-05 -8.91962179e-05 -8.75643155e-05
#  -8.59601835e-05 -8.43834115e-05 -8.28335936e-05 -8.13103283e-05
#  -7.98132177e-05 -7.83418648e-05 -7.68958779e-05 -7.54748698e-05
#  -7.40784578e-05 -7.27062636e-05 -7.13579136e-05 -7.00330385e-05
#  -6.87312738e-05 -6.74522593e-05 -6.61956393e-05 -6.49610627e-05
#  -6.37481828e-05 -6.25566576e-05 -6.13861494e-05 -6.02363242e-05
#  -5.91068490e-05 -5.79973975e-05 -5.69076474e-05 -5.58372809e-05
#  -5.47859840e-05 -5.37534470e-05 -5.27393643e-05 -5.17434345e-05
#  -5.07653601e-05 -4.98048480e-05 -4.88616090e-05 -4.79353582e-05
#  -4.70258147e-05 -4.61327018e-05 -4.52557468e-05 -4.43946805e-05
#  -4.35492347e-05 -4.27191478e-05 -4.19041622e-05 -4.11040236e-05
#  -4.03184813e-05 -3.95472883e-05 -3.87902007e-05 -3.80469787e-05
#  -3.73173856e-05 -3.66011883e-05 -3.58981574e-05 -3.52080670e-05
#  -3.45306945e-05 -3.38658211e-05 -3.32132313e-05 -3.25727117e-05
#  -3.19440528e-05 -3.13270493e-05 -3.07214988e-05 -3.01272018e-05
#  -2.95439618e-05 -2.89715852e-05 -2.84098813e-05 -2.78586626e-05
#  -2.73177442e-05 -2.67869444e-05 -2.62660843e-05 -2.57549881e-05
#  -2.52534828e-05 -2.47613979e-05 -2.42785655e-05 -2.38048214e-05
#  -2.33400040e-05 -2.28839541e-05 -2.24365149e-05 -2.19975320e-05
#  -2.15668536e-05 -2.11443302e-05 -2.07298148e-05 -2.03231628e-05
#  -1.99242320e-05 -1.95328827e-05 -1.91489776e-05 -1.87723813e-05
#  -1.84029612e-05 -1.80405872e-05 -1.76851315e-05 -1.73364681e-05
#  -1.69944729e-05 -1.66590240e-05 -1.63300015e-05 -1.60072873e-05
#  -1.56907655e-05 -1.53803221e-05 -1.50758452e-05 -1.47772248e-05
#  -1.44843525e-05 -1.41971223e-05 -1.39154302e-05 -1.36391740e-05
#  -1.33682531e-05 -1.31025686e-05 -1.28420232e-05 -1.25865212e-05
#  -1.23359685e-05 -1.20902728e-05 -1.18493432e-05 -1.16130906e-05
#  -1.13814276e-05 -1.11542679e-05 -1.09315272e-05 -1.07131230e-05
#  -1.04989741e-05 -1.02890006e-05 -1.00831240e-05 -9.88126710e-06
#  -9.68335394e-06 -9.48930998e-06 -9.29906201e-06 -9.11253810e-06
#  -8.92966769e-06 -8.75038149e-06 -8.57461134e-06 -8.40229074e-06
#  -8.23335441e-06 -8.06773815e-06 -7.90537881e-06 -7.74621434e-06
#  -7.59018376e-06 -7.43722717e-06 -7.28728573e-06 -7.14030169e-06
#  -6.99621838e-06 -6.85498020e-06 -6.71653246e-06 -6.58082171e-06
#  -6.44779564e-06 -6.31740283e-06 -6.18959270e-06 -6.06431556e-06
#  -5.94152258e-06 -5.82116581e-06 -5.70319817e-06 -5.58757343e-06
#  -5.47424625e-06 -5.36317216e-06 -5.25430745e-06 -5.14760934e-06
#  -5.04303604e-06 -4.94054648e-06 -4.84010029e-06 -4.74165779e-06
#  -4.64518001e-06 -4.55062870e-06 -4.45796627e-06 -4.36715587e-06
#  -4.27816133e-06 -4.19094719e-06 -4.10547863e-06 -4.02172152e-06
#  -3.93964259e-06 -3.85920912e-06 -3.78038898e-06 -3.70315058e-06
#  -3.62746290e-06 -3.55329551e-06 -3.48061850e-06 -3.40940255e-06
#  -3.33961891e-06 -3.27123938e-06 -3.20423628e-06 -3.13858251e-06
#  -3.07425162e-06 -3.01121764e-06 -2.94945503e-06 -2.88893871e-06
#  -2.82964407e-06 -2.77154694e-06 -2.71462360e-06 -2.65885078e-06
#  -2.60420567e-06 -2.55066592e-06 -2.49820957e-06 -2.44681516e-06
#  -2.39646173e-06 -2.34712868e-06 -2.29879580e-06 -2.25144321e-06
#  -2.20505142e-06 -2.15960128e-06 -2.11507401e-06 -2.07145121e-06
#  -2.02871481e-06 -1.98684714e-06 -1.94583081e-06 -1.90564888e-06
#  -1.86628478e-06 -1.82772222e-06 -1.78994519e-06 -1.75293801e-06
#  -1.71668525e-06 -1.68117178e-06 -1.64638278e-06 -1.61230370e-06
#  -1.57892028e-06 -1.54621856e-06 -1.51418482e-06 -1.48280572e-06
#  -1.45206815e-06 -1.42195928e-06 -1.39246647e-06 -1.36357733e-06
#  -1.33527970e-06 -1.30756165e-06 -1.28041148e-06 -1.25381774e-06
#  -1.22776918e-06 -1.20225480e-06 -1.17726380e-06 -1.15278568e-06
#  -1.12881012e-06 -1.10532698e-06 -1.08232633e-06 -1.05979841e-06
#  -1.03773363e-06 -1.01612260e-06 -9.94956131e-07 -9.74225188e-07
#  -9.53920937e-07 -9.34034708e-07 -9.14558037e-07 -8.95482660e-07
#  -8.76800460e-07 -8.58503467e-07 -8.40583859e-07 -8.23033959e-07
#  -8.05846241e-07 -7.89013322e-07 -7.72527971e-07 -7.56383101e-07
#  -7.40571770e-07 -7.25087168e-07 -7.09922667e-07 -6.95071773e-07
#  -6.80528109e-07 -6.66285415e-07 -6.52337547e-07 -6.38678478e-07
#  -6.25302302e-07 -6.12203224e-07 -5.99375572e-07 -5.86813788e-07
#  -5.74512423e-07 -5.62466148e-07 -5.50669773e-07 -5.39118200e-07
#  -5.27806427e-07 -5.16729543e-07 -5.05882730e-07 -4.95261265e-07
#  -4.84860515e-07 -4.74675944e-07 -4.64703107e-07 -4.54937650e-07
#  -4.45375302e-07 -4.36011907e-07 -4.26843397e-07 -4.17865778e-07
#  -4.09075129e-07 -4.00467604e-07 -3.92039430e-07 -3.83786910e-07
#  -3.75706418e-07 -3.67794404e-07 -3.60047390e-07 -3.52461970e-07
#  -3.45034808e-07 -3.37762661e-07 -3.30642342e-07 -3.23670726e-07
#  -3.16844745e-07 -3.10161390e-07 -3.03617711e-07 -2.97210816e-07
#  -2.90937872e-07 -2.84796104e-07 -2.78782795e-07 -2.72895281e-07
#  -2.67130968e-07 -2.61487319e-07 -2.55961843e-07 -2.50552097e-07
#  -2.45255684e-07 -2.40070251e-07 -2.34993496e-07 -2.30023158e-07
#  -2.25157027e-07 -2.20392936e-07 -2.15728765e-07 -2.11162438e-07
#  -2.06691934e-07 -2.02315272e-07 -1.98030507e-07 -1.93835731e-07
#  -1.89729071e-07 -1.85708692e-07 -1.81772798e-07 -1.77919625e-07
#  -1.74147450e-07 -1.70454585e-07 -1.66839373e-07 -1.63300204e-07
#  -1.59835502e-07 -1.56443720e-07 -1.53123340e-07 -1.49872875e-07
#  -1.46690864e-07 -1.43575877e-07 -1.40526513e-07 -1.37541399e-07
#  -1.34619192e-07 -1.31758575e-07 -1.28958264e-07 -1.26217005e-07
#  -1.23533570e-07 -1.20906752e-07 -1.18335369e-07 -1.15818261e-07
#  -1.13354291e-07 -1.10942345e-07 -1.08581331e-07 -1.06270183e-07
#  -1.04007854e-07 -1.01793320e-07 -9.96255843e-08 -9.75036722e-08
#  -9.54266259e-08 -9.33935061e-08 -9.14033916e-08 -8.94553797e-08
#  -8.75485854e-08 -8.56821422e-08 -8.38552017e-08 -8.20669337e-08
#  -8.03165241e-08 -7.86031799e-08 -7.69261270e-08 -7.52846059e-08
#  -7.36778713e-08 -7.21051923e-08 -7.05658523e-08 -6.90591493e-08
#  -6.75843953e-08 -6.61409170e-08 -6.47280551e-08 -6.33451644e-08
#  -6.19916133e-08 -6.06667880e-08 -5.93700861e-08 -5.81009168e-08
#  -5.68587005e-08 -5.56428691e-08 -5.44528656e-08 -5.32881445e-08
#  -5.21481718e-08 -5.10324244e-08 -4.99403907e-08 -4.88715692e-08
#  -4.78254725e-08 -4.68016235e-08 -4.57995538e-08 -4.48188044e-08
#  -4.38589249e-08 -4.29194740e-08 -4.20000194e-08 -4.11001375e-08
#  -4.02194140e-08 -3.93574433e-08 -3.85138278e-08 -3.76881804e-08
#  -3.68801233e-08 -3.60892856e-08 -3.53153038e-08 -3.45578213e-08
#  -3.38164884e-08 -3.30909629e-08 -3.23809091e-08 -3.16859988e-08
#  -3.10059108e-08 -3.03403303e-08 -2.96889498e-08 -2.90514702e-08
#  -2.84275981e-08 -2.78170458e-08 -2.72195310e-08 -2.66347769e-08
#  -2.60625126e-08 -2.55024725e-08 -2.49543966e-08 -2.44180306e-08
#  -2.38931255e-08 -2.33794374e-08 -2.28767294e-08 -2.23847695e-08
#  -2.19033301e-08 -2.14321878e-08 -2.09711239e-08 -2.05199238e-08
#  -2.00783775e-08 -1.96462793e-08 -1.92234279e-08 -1.88096264e-08
#  -1.84046816e-08 -1.80084060e-08 -1.76206159e-08 -1.72411316e-08
#  -1.68697765e-08 -1.65063775e-08 -1.61507651e-08 -1.58027732e-08
#  -1.54622391e-08 -1.51290036e-08 -1.48029110e-08 -1.44838087e-08
#  -1.41715478e-08 -1.38659834e-08 -1.35669734e-08 -1.32743782e-08
#  -1.29880612e-08 -1.27078883e-08 -1.24337283e-08 -1.21654526e-08
#  -1.19029354e-08 -1.16460535e-08 -1.13946864e-08 -1.11487163e-08
#  -1.09080285e-08 -1.06725108e-08 -1.04420531e-08 -1.02165474e-08
#  -9.99588792e-09 -9.77997085e-09 -9.56869468e-09 -9.36195999e-09
#  -9.15966950e-09 -8.96172806e-09 -8.76804240e-09 -8.57852189e-09
#  -8.39307795e-09 -8.21162365e-09 -8.03407378e-09 -7.86034478e-09
#  -7.69035478e-09 -7.52402359e-09 -7.36127271e-09 -7.20202532e-09
#  -7.04620625e-09 -6.89374192e-09 -6.74456053e-09 -6.59859221e-09
#  -6.45576840e-09 -6.31602186e-09 -6.17928667e-09 -6.04549824e-09
#  -5.91459327e-09 -5.78650982e-09 -5.66118723e-09 -5.53856619e-09
#  -5.41858864e-09 -5.30119776e-09 -5.18633839e-09 -5.07395649e-09
#  -4.96399904e-09 -4.85641406e-09 -4.75115062e-09 -4.64815879e-09
#  -4.54738969e-09 -4.44879549e-09 -4.35232935e-09 -4.25794551e-09
#  -4.16559909e-09 -4.07524645e-09 -3.98684502e-09 -3.90035302e-09
#  -3.81572950e-09 -3.73293430e-09 -3.65192807e-09 -3.57267227e-09
#  -3.49512916e-09 -3.41926183e-09 -3.34503415e-09 -3.27241078e-09
#  -3.20135715e-09 -3.13183970e-09 -3.06382554e-09 -2.99728241e-09
#  -2.93217868e-09 -2.86848334e-09 -2.80616604e-09 -2.74519702e-09
#  -2.68554718e-09 -2.62718803e-09 -2.57009173e-09 -2.51423097e-09
#  -2.45957922e-09 -2.40611057e-09 -2.35379966e-09 -2.30262157e-09
#  -2.25255191e-09 -2.20356676e-09 -2.15564268e-09 -2.10875675e-09
#  -2.06288650e-09 -2.01800999e-09 -1.97410574e-09 -1.93115270e-09
#  -1.88913045e-09 -1.84801905e-09 -1.80779891e-09 -1.76845082e-09
#  -1.72995597e-09 -1.69229591e-09 -1.65545258e-09 -1.61940830e-09
#  -1.58414576e-09 -1.54964805e-09 -1.51589860e-09 -1.48288121e-09
#  -1.45058015e-09 -1.41898006e-09 -1.38806583e-09 -1.35782267e-09
#  -1.32823608e-09 -1.29929184e-09 -1.27097604e-09 -1.24327504e-09
#  -1.21617553e-09 -1.18966445e-09 -1.16372906e-09 -1.13835685e-09
#  -1.11353573e-09 -1.08925384e-09 -1.06549958e-09 -1.04226154e-09
#  -1.01952857e-09 -9.97289701e-10 -9.75534230e-10 -9.54251657e-10
#  -9.33431712e-10 -9.13064351e-10 -8.93139751e-10 -8.73648279e-10
#  -8.54580596e-10 -8.35927592e-10 -8.17680332e-10 -7.99830050e-10
#  -7.82368152e-10 -7.65286216e-10 -7.48575990e-10 -7.32229396e-10
#  -7.16238525e-10 -7.00595641e-10 -6.85293178e-10 -6.70323733e-10
#  -6.55680062e-10 -6.41355160e-10 -6.27342163e-10 -6.13634336e-10
#  -6.00225075e-10 -5.87107904e-10 -5.74276479e-10 -5.61724583e-10
#  -5.49446132e-10 -5.37435169e-10 -5.25685868e-10 -5.14192533e-10
#  -5.02949585e-10 -4.91951576e-10 -4.81193237e-10 -4.70669405e-10
#  -4.60375010e-10 -4.50305082e-10 -4.40454749e-10 -4.30819233e-10
#  -4.21393857e-10 -4.12174039e-10 -4.03155295e-10 -3.94333238e-10
#  -3.85703580e-10 -3.77262123e-10 -3.69004754e-10 -3.60927505e-10
#  -3.53026495e-10 -3.45297918e-10 -3.37738038e-10 -3.30343193e-10
#  -3.23109792e-10 -3.16034316e-10 -3.09113319e-10 -3.02343428e-10
#  -2.95721340e-10 -2.89243825e-10 -2.82907726e-10 -2.76709951e-10
#  -2.70647476e-10 -2.64717389e-10 -2.58916837e-10 -2.53243017e-10
#  -2.47693184e-10 -2.42264641e-10 -2.36954747e-10 -2.31760913e-10
#  -2.26680603e-10 -2.21711332e-10 -2.16850671e-10 -2.12096242e-10
#  -2.07445719e-10 -2.02896832e-10 -1.98447344e-10 -1.94095109e-10
#  -1.89838031e-10 -1.85674058e-10 -1.81601171e-10 -1.77617391e-10
#  -1.73720779e-10 -1.69909432e-10 -1.66181485e-10 -1.62535113e-10
#  -1.58968527e-10 -1.55479977e-10 -1.52067753e-10 -1.48730180e-10
#  -1.45465622e-10 -1.42272471e-10 -1.39149180e-10 -1.36094249e-10
#  -1.33106201e-10 -1.30183587e-10 -1.27324987e-10 -1.24529006e-10
#  -1.21794276e-10 -1.19119457e-10 -1.16503236e-10 -1.13944328e-10
#  -1.11441472e-10 -1.08993436e-10 -1.06599017e-10 -1.04257035e-10
#  -1.01966338e-10 -9.97257943e-11 -9.75343225e-11 -9.53908677e-11
#  -9.32943936e-11 -9.12438827e-11 -8.92383361e-11 -8.72767740e-11
#  -8.53582352e-11 -8.34817773e-11 -8.16464768e-11 -7.98514288e-11
#  -7.80957475e-11 -7.63785656e-11 -7.46990349e-11 -7.30563256e-11
#  -7.14496272e-11 -6.98781436e-11 -6.83410999e-11 -6.68377577e-11
#  -6.53673926e-11 -6.39292931e-11 -6.25227602e-11 -6.11471080e-11
#  -5.98016631e-11 -5.84857649e-11 -5.71987655e-11 -5.59400299e-11
#  -5.47089357e-11 -5.35048734e-11 -5.23272462e-11 -5.11754699e-11
#  -5.00489733e-11 -4.89471977e-11 -4.78695975e-11 -4.68156344e-11
#  -4.57847922e-11 -4.47765768e-11 -4.37905024e-11 -4.28260919e-11
#  -4.18828761e-11 -4.09603948e-11 -4.00581958e-11 -3.91758355e-11
#  -3.83128786e-11 -3.74688984e-11 -3.66434763e-11 -3.58362024e-11
#  -3.50466751e-11 -3.42745013e-11 -3.35192960e-11 -3.27806831e-11
#  -3.20582945e-11 -3.13517707e-11 -3.06607565e-11 -2.99849138e-11
#  -2.93239193e-11 -2.86774553e-11 -2.80452096e-11 -2.74268750e-11
#  -2.68221500e-11 -2.62307383e-11 -2.56523491e-11 -2.50866967e-11
#  -2.45335011e-11 -2.39924874e-11 -2.34633863e-11 -2.29459336e-11
#  -2.24398708e-11 -2.19449444e-11 -2.14609066e-11 -2.09875147e-11
#  -2.05245315e-11 -2.00717253e-11 -1.96288681e-11 -1.91957382e-11
#  -1.87721290e-11 -1.83578382e-11 -1.79526667e-11 -1.75564187e-11
#  -1.71689017e-11 -1.67899266e-11 -1.64193074e-11 -1.60568616e-11
#  -1.57024099e-11 -1.53557762e-11 -1.50167878e-11 -1.46852753e-11
#  -1.43610726e-11 -1.40440167e-11 -1.37339483e-11 -1.34307109e-11
#  -1.31341516e-11 -1.28441208e-11 -1.25604721e-11 -1.22830623e-11
#  -1.20117510e-11 -1.17464012e-11 -1.14868873e-11 -1.12330860e-11
#  -1.09848761e-11 -1.07421385e-11 -1.05047556e-11 -1.02726121e-11
#  -1.00455946e-11 -9.82359131e-12 -9.60649272e-12 -9.39419107e-12
#  -9.18658055e-12 -8.98355731e-12 -8.78501939e-12 -8.59086676e-12
#  -8.40100134e-12 -8.21532695e-12 -8.03374935e-12 -7.85617622e-12
#  -7.68251716e-12 -7.51268371e-12 -7.34658933e-12 -7.18414939e-12
#  -7.02528071e-12 -6.86990298e-12 -6.71794324e-12 -6.56933011e-12
#  -6.42399329e-12 -6.28186351e-12 -6.14287258e-12 -6.00695337e-12
#  -5.87403981e-12 -5.74406691e-12 -5.61697070e-12 -5.49268831e-12
#  -5.37115791e-12 -5.25231875e-12 -5.13611113e-12 -5.02247641e-12
#  -4.91135701e-12 -4.80269643e-12 -4.69643920e-12 -4.59253095e-12
#  -4.49091834e-12 -4.39154911e-12 -4.29437205e-12 -4.19933702e-12
#  -4.10639494e-12 -4.01549779e-12 -3.92659895e-12 -3.83966118e-12
#  -3.75464453e-12 -3.67150665e-12 -3.59020609e-12 -3.51070233e-12] [2.00000000e+00 1.99945840e+00 1.99786709e+00 1.99527505e+00
#  1.99172955e+00 1.98727615e+00 1.98195886e+00 1.97582014e+00
#  1.96890097e+00 1.96124080e+00 1.95287765e+00 1.94384827e+00
#  1.93418807e+00 1.92393119e+00 1.91311046e+00 1.90175746e+00
#  1.88990269e+00 1.87757556e+00 1.86480437e+00 1.85161637e+00
#  1.83803769e+00 1.82409348e+00 1.80980798e+00 1.79520455e+00
#  1.78030565e+00 1.76513286e+00 1.74970685e+00 1.73404744e+00
#  1.71817374e+00 1.70210412e+00 1.68585623e+00 1.66944701e+00
#  1.65289269e+00 1.63620875e+00 1.61941006e+00 1.60251088e+00
#  1.58552495e+00 1.56846541e+00 1.55134481e+00 1.53417519e+00
#  1.51696794e+00 1.49973400e+00 1.48248385e+00 1.46522752e+00
#  1.44797461e+00 1.43073426e+00 1.41351518e+00 1.39632561e+00
#  1.37917338e+00 1.36206598e+00 1.34501057e+00 1.32801396e+00
#  1.31108262e+00 1.29422267e+00 1.27743992e+00 1.26073977e+00
#  1.24412740e+00 1.22760770e+00 1.21118533e+00 1.19486466e+00
#  1.17864985e+00 1.16254476e+00 1.14655302e+00 1.13067798e+00
#  1.11492280e+00 1.09929045e+00 1.08378372e+00 1.06840520e+00
#  1.05315731e+00 1.03804226e+00 1.02306210e+00 1.00821866e+00
#  9.93513616e-01 9.78948526e-01 9.64524814e-01 9.50243765e-01
#  9.36106537e-01 9.22114149e-01 9.08267502e-01 8.94567329e-01
#  8.81014252e-01 8.67608801e-01 8.54351415e-01 8.41242442e-01
#  8.28282140e-01 8.15470676e-01 8.02808126e-01 7.90294480e-01
#  7.77929611e-01 7.65713324e-01 7.53645368e-01 7.41725430e-01
#  7.29953142e-01 7.18328075e-01 7.06849742e-01 6.95517596e-01
#  6.84331038e-01 6.73289385e-01 6.62391913e-01 6.51637862e-01
#  6.41026438e-01 6.30556814e-01 6.20228125e-01 6.10039473e-01
#  5.99989925e-01 5.90078517e-01 5.80304234e-01 5.70666028e-01
#  5.61162834e-01 5.51793568e-01 5.42557128e-01 5.33452398e-01
#  5.24478240e-01 5.15633502e-01 5.06917012e-01 4.98327584e-01
#  4.89863998e-01 4.81525023e-01 4.73309425e-01 4.65215963e-01
#  4.57243390e-01 4.49390455e-01 4.41655901e-01 4.34038466e-01
#  4.26536880e-01 4.19149872e-01 4.11876150e-01 4.04714424e-01
#  3.97663404e-01 3.90721805e-01 3.83888343e-01 3.77161737e-01
#  3.70540709e-01 3.64023983e-01 3.57610286e-01 3.51298347e-01
#  3.45086892e-01 3.38974647e-01 3.32960345e-01 3.27042727e-01
#  3.21220542e-01 3.15492547e-01 3.09857504e-01 3.04314186e-01
#  2.98861371e-01 2.93497846e-01 2.88222403e-01 2.83033837e-01
#  2.77930950e-01 2.72912556e-01 2.67977477e-01 2.63124547e-01
#  2.58352609e-01 2.53660518e-01 2.49047138e-01 2.44511344e-01
#  2.40052019e-01 2.35668058e-01 2.31358361e-01 2.27121838e-01
#  2.22957410e-01 2.18864009e-01 2.14840581e-01 2.10886080e-01
#  2.06999473e-01 2.03179738e-01 1.99425864e-01 1.95736853e-01
#  1.92111717e-01 1.88549476e-01 1.85049160e-01 1.81609811e-01
#  1.78230484e-01 1.74910242e-01 1.71648162e-01 1.68443331e-01
#  1.65294848e-01 1.62201823e-01 1.59163377e-01 1.56178643e-01
#  1.53246764e-01 1.50366896e-01 1.47538198e-01 1.44759848e-01
#  1.42031030e-01 1.39350941e-01 1.36718788e-01 1.34133788e-01
#  1.31595170e-01 1.29102170e-01 1.26654040e-01 1.24250038e-01
#  1.21889435e-01 1.19571511e-01 1.17295556e-01 1.15060867e-01
#  1.12866756e-01 1.10712542e-01 1.08597555e-01 1.06521135e-01
#  1.04482629e-01 1.02481395e-01 1.00516800e-01 9.85882201e-02
#  9.66950416e-02 9.48366591e-02 9.30124769e-02 9.12219087e-02
#  8.94643755e-02 8.77393054e-02 8.60461394e-02 8.43843269e-02
#  8.27533250e-02 8.11525986e-02 7.95816205e-02 7.80398717e-02
#  7.65268406e-02 7.50420237e-02 7.35849255e-02 7.21550583e-02
#  7.07519420e-02 6.93751048e-02 6.80240826e-02 6.66984177e-02
#  6.53976573e-02 6.41213613e-02 6.28690963e-02 6.16404353e-02
#  6.04349577e-02 5.92522492e-02 5.80919022e-02 5.69535150e-02
#  5.58366926e-02 5.47410462e-02 5.36661936e-02 5.26117587e-02
#  5.15773720e-02 5.05626703e-02 4.95672967e-02 4.85908999e-02
#  4.76331329e-02 4.66936585e-02 4.57721451e-02 4.48682657e-02
#  4.39816989e-02 4.31121280e-02 4.22592413e-02 4.14227325e-02
#  4.06023000e-02 3.97976474e-02 3.90084833e-02 3.82345215e-02
#  3.74754807e-02 3.67310846e-02 3.60010621e-02 3.52851456e-02
#  3.45830739e-02 3.38945914e-02 3.32194462e-02 3.25573906e-02
#  3.19081808e-02 3.12715771e-02 3.06473436e-02 3.00352485e-02
#  2.94350642e-02 2.88465667e-02 2.82695364e-02 2.77037574e-02
#  2.71490179e-02 2.66051096e-02 2.60718283e-02 2.55489745e-02
#  2.50363522e-02 2.45337686e-02 2.40410340e-02 2.35579618e-02
#  2.30843689e-02 2.26200749e-02 2.21649030e-02 2.17186793e-02
#  2.12812331e-02 2.08523971e-02 2.04320070e-02 2.00199010e-02
#  1.96159212e-02 1.92199132e-02 1.88317251e-02 1.84512073e-02
#  1.80782131e-02 1.77125980e-02 1.73542202e-02 1.70029404e-02
#  1.66586217e-02 1.63211300e-02 1.59903335e-02 1.56661029e-02
#  1.53483113e-02 1.50368344e-02 1.47315508e-02 1.44323412e-02
#  1.41390883e-02 1.38516770e-02 1.35699938e-02 1.32939276e-02
#  1.30233691e-02 1.27582111e-02 1.24983483e-02 1.22436776e-02
#  1.19940977e-02 1.17495092e-02 1.15098149e-02 1.12749198e-02
#  1.10447306e-02 1.08191555e-02 1.05981043e-02 1.03814884e-02
#  1.01692210e-02 9.96121660e-03 9.75739148e-03 9.55766347e-03
#  9.36195201e-03 9.17017808e-03 8.98226408e-03 8.79813444e-03
#  8.61771503e-03 8.44093297e-03 8.26771670e-03 8.09799588e-03
#  7.93170148e-03 7.76876573e-03 7.60912213e-03 7.45270546e-03
#  7.29945177e-03 7.14929840e-03 7.00218375e-03 6.85804775e-03
#  6.71683166e-03 6.57847775e-03 6.44292932e-03 6.31013067e-03
#  6.18002711e-03 6.05256498e-03 5.92769162e-03 5.80535539e-03
#  5.68550565e-03 5.56809279e-03 5.45306811e-03 5.34038397e-03
#  5.22999393e-03 5.12185234e-03 5.01591439e-03 4.91213603e-03
#  4.81047407e-03 4.71088607e-03 4.61333044e-03 4.51776638e-03
#  4.42415388e-03 4.33245376e-03 4.24262756e-03 4.15463767e-03
#  4.06844740e-03 3.98402076e-03 3.90132236e-03 3.82031747e-03
#  3.74097200e-03 3.66325251e-03 3.58712617e-03 3.51256082e-03
#  3.43952493e-03 3.36798760e-03 3.29791853e-03 3.22928807e-03
#  3.16206735e-03 3.09622799e-03 3.03174212e-03 2.96858240e-03
#  2.90672197e-03 2.84613451e-03 2.78679418e-03 2.72867566e-03
#  2.67175415e-03 2.61600533e-03 2.56140536e-03 2.50793095e-03
#  2.45555938e-03 2.40426834e-03 2.35403591e-03 2.30484058e-03
#  2.25666126e-03 2.20947724e-03 2.16326822e-03 2.11801431e-03
#  2.07369602e-03 2.03029426e-03 1.98779029e-03 1.94616586e-03
#  1.90540312e-03 1.86548455e-03 1.82639294e-03 1.78811141e-03
#  1.75062338e-03 1.71391262e-03 1.67796320e-03 1.64275950e-03
#  1.60828625e-03 1.57452848e-03 1.54147148e-03 1.50910098e-03
#  1.47740298e-03 1.44636373e-03 1.41596974e-03 1.38620777e-03
#  1.35706484e-03 1.32852821e-03 1.30058542e-03 1.27322422e-03
#  1.24643266e-03 1.22019900e-03 1.19451175e-03 1.16935974e-03
#  1.14473201e-03 1.12061779e-03 1.09700651e-03 1.07388780e-03
#  1.05125151e-03 1.02908768e-03 1.00738652e-03 9.86138495e-04
#  9.65334231e-04 9.44964546e-04 9.25020486e-04 9.05493313e-04
#  8.86374445e-04 8.67655461e-04 8.49328095e-04 8.31384245e-04
#  8.13815964e-04 7.96615464e-04 7.79775116e-04 7.63287452e-04
#  7.47145155e-04 7.31341054e-04 7.15868176e-04 7.00719688e-04
#  6.85888885e-04 6.71369186e-04 6.57154135e-04 6.43237403e-04
#  6.29612786e-04 6.16274203e-04 6.03215701e-04 5.90431452e-04
#  5.77915744e-04 5.65662995e-04 5.53667770e-04 5.41924734e-04
#  5.30428652e-04 5.19174388e-04 5.08156905e-04 4.97371264e-04
#  4.86812627e-04 4.76476252e-04 4.66357501e-04 4.56451829e-04
#  4.46754781e-04 4.37262023e-04 4.27969317e-04 4.18872502e-04
#  4.09967495e-04 4.01250291e-04 3.92716965e-04 3.84363667e-04
#  3.76186628e-04 3.68182156e-04 3.60346638e-04 3.52676534e-04
#  3.45168380e-04 3.37818811e-04 3.30624520e-04 3.23582267e-04
#  3.16688871e-04 3.09941212e-04 3.03336233e-04 2.96870939e-04
#  2.90542395e-04 2.84347730e-04 2.78284132e-04 2.72348844e-04
#  2.66539186e-04 2.60852535e-04 2.55286319e-04 2.49838015e-04
#  2.44505145e-04 2.39285283e-04 2.34176052e-04 2.29175121e-04
#  2.24280209e-04 2.19489085e-04 2.14799560e-04 2.10209498e-04
#  2.05716819e-04 2.01319483e-04 1.97015488e-04 1.92802871e-04
#  1.88679707e-04 1.84644109e-04 1.80694230e-04 1.76828259e-04
#  1.73044425e-04 1.69340994e-04 1.65716266e-04 1.62168588e-04
#  1.58696346e-04 1.55297951e-04 1.51971850e-04 1.48716515e-04
#  1.45530452e-04 1.42412195e-04 1.39360310e-04 1.36373391e-04
#  1.33450064e-04 1.30588982e-04 1.27788830e-04 1.25048328e-04
#  1.22366220e-04 1.19741273e-04 1.17172281e-04 1.14658058e-04
#  1.12197443e-04 1.09789299e-04 1.07432514e-04 1.05125997e-04
#  1.02868683e-04 1.00659527e-04 9.84975145e-05 9.63816513e-05
#  9.43109624e-05 9.22844914e-05 9.03013007e-05 8.83604715e-05
#  8.64611034e-05 8.46023150e-05 8.27832436e-05 8.10030451e-05
#  7.92608922e-05 7.75559792e-05 7.58875202e-05 7.42547439e-05
#  7.26568939e-05 7.10932283e-05 6.95630202e-05 6.80655572e-05
#  6.66001419e-05 6.51660915e-05 6.37627378e-05 6.23894269e-05
#  6.10455192e-05 5.97303929e-05 5.84434385e-05 5.71840580e-05
#  5.59516648e-05 5.47456841e-05 5.35655528e-05 5.24107191e-05
#  5.12806430e-05 5.01747961e-05 4.90926614e-05 4.80337322e-05
#  4.69975163e-05 4.59835322e-05 4.49913073e-05 4.40203783e-05
#  4.30702908e-05 4.21405998e-05 4.12308692e-05 4.03406721e-05
#  3.94695908e-05 3.86172166e-05 3.77831491e-05 3.69669984e-05
#  3.61683840e-05 3.53869328e-05 3.46222789e-05 3.38740635e-05
#  3.31419350e-05 3.24255490e-05 3.17245681e-05 3.10386624e-05
#  3.03675089e-05 2.97107915e-05 2.90682013e-05 2.84394379e-05
#  2.78242068e-05 2.72222192e-05 2.66331918e-05 2.60568471e-05
#  2.54929130e-05 2.49411233e-05 2.44012174e-05 2.38729402e-05
#  2.33560421e-05 2.28502790e-05 2.23554134e-05 2.18712131e-05
#  2.13974500e-05 2.09339008e-05 2.04803464e-05 2.00365722e-05
#  1.96023680e-05 1.91775281e-05 1.87618512e-05 1.83551404e-05
#  1.79572027e-05 1.75678505e-05 1.71869007e-05 1.68141734e-05
#  1.64494925e-05 1.60926851e-05 1.57435821e-05 1.54020175e-05
#  1.50678292e-05 1.47408582e-05 1.44209493e-05 1.41079503e-05
#  1.38017127e-05 1.35020922e-05 1.32089471e-05 1.29221384e-05
#  1.26415300e-05 1.23669885e-05 1.20983830e-05 1.18355856e-05
#  1.15784710e-05 1.13269168e-05 1.10808030e-05 1.08400123e-05
#  1.06044308e-05 1.03739469e-05 1.01484512e-05 9.92783639e-06
#  9.71199721e-06 9.50083066e-06 9.29423587e-06 9.09211411e-06
#  8.89436877e-06 8.70090540e-06 8.51163141e-06 8.32645690e-06
#  8.14529399e-06 7.96805648e-06 7.79465983e-06 7.62502122e-06
#  7.45905948e-06 7.29669513e-06 7.13785036e-06 6.98244907e-06
#  6.83041680e-06 6.68168065e-06 6.53616956e-06 6.39381435e-06
#  6.25454716e-06 6.11830147e-06 5.98501205e-06 5.85461499e-06
#  5.72704769e-06 5.60224890e-06 5.48015864e-06 5.36071826e-06
#  5.24387039e-06 5.12955889e-06 5.01772927e-06 4.90832814e-06
#  4.80130316e-06 4.69660299e-06 4.59417736e-06 4.49397697e-06
#  4.39595361e-06 4.30006004e-06 4.20625009e-06 4.11447859e-06
#  4.02470130e-06 3.93687519e-06 3.85095829e-06 3.76690945e-06
#  3.68468828e-06 3.60425523e-06 3.52557154e-06 3.44859924e-06
#  3.37330117e-06 3.29964098e-06 3.22758311e-06 3.15709277e-06
#  3.08813594e-06 3.02067960e-06 2.95469140e-06 2.89013962e-06
#  2.82699315e-06 2.76522150e-06 2.70479483e-06 2.64568391e-06
#  2.58786011e-06 2.53129545e-06 2.47596259e-06 2.42183469e-06
#  2.36888569e-06 2.31709018e-06 2.26642323e-06 2.21686042e-06
#  2.16837779e-06 2.12095187e-06 2.07455967e-06 2.02917870e-06
#  1.98478693e-06 1.94136284e-06 1.89888537e-06 1.85733388e-06
#  1.81668838e-06 1.77692931e-06 1.73803747e-06 1.69999408e-06
#  1.66278068e-06 1.62637922e-06 1.59077202e-06 1.55594176e-06
#  1.52187150e-06 1.48854468e-06 1.45594511e-06 1.42405691e-06
#  1.39286472e-06 1.36235351e-06 1.33250850e-06 1.30331525e-06
#  1.27475956e-06 1.24682754e-06 1.21950560e-06 1.19278043e-06
#  1.16663898e-06 1.14106853e-06 1.11605662e-06 1.09159105e-06
#  1.06766000e-06 1.04425191e-06 1.02135544e-06 9.98959473e-07
#  9.77053113e-07 9.55625679e-07 9.34666717e-07 9.14165989e-07
#  8.94113481e-07 8.74499398e-07 8.55314166e-07 8.36548393e-07
#  8.18192980e-07 8.00239053e-07 7.82677906e-07 7.65501001e-07
#  7.48699968e-07 7.32266606e-07 7.16192881e-07 7.00470927e-07
#  6.85093047e-07 6.70051710e-07 6.55339555e-07 6.40949377e-07
#  6.26874131e-07 6.13107004e-07 5.99641321e-07 5.86470535e-07
#  5.73588225e-07 5.60988097e-07 5.48663983e-07 5.36609844e-07
#  5.24819766e-07 5.13287962e-07 5.02008773e-07 4.90976665e-07
#  4.80186222e-07 4.69632153e-07 4.59309346e-07 4.49212786e-07
#  4.39337557e-07 4.29678835e-07 4.20231891e-07 4.10992094e-07
#  4.01954903e-07 3.93115877e-07 3.84470666e-07 3.76015018e-07
#  3.67744773e-07 3.59655864e-07 3.51744304e-07 3.44006248e-07
#  3.36437938e-07 3.29035686e-07 3.21795875e-07 3.14714956e-07
#  3.07789454e-07 3.01015961e-07 2.94391142e-07 2.87911729e-07
#  2.81574528e-07 2.75376412e-07 2.69314327e-07 2.63385281e-07
#  2.57586349e-07 2.51914714e-07 2.46367619e-07 2.40942356e-07
#  2.35636268e-07 2.30446750e-07 2.25371249e-07 2.20407263e-07
#  2.15552341e-07 2.10804084e-07 2.06160144e-07 2.01618224e-07
#  1.97176080e-07 1.92831515e-07 1.88582374e-07 1.84426583e-07
#  1.80362121e-07 1.76387006e-07 1.72499292e-07 1.68697069e-07
#  1.64978466e-07 1.61341648e-07 1.57784817e-07 1.54306211e-07
#  1.50904107e-07 1.47576818e-07 1.44322693e-07 1.41140119e-07
#  1.38027520e-07 1.34983345e-07 1.32006106e-07 1.29094356e-07
#  1.26246673e-07 1.23461664e-07 1.20737959e-07 1.18074216e-07
#  1.15469118e-07 1.12921376e-07 1.10429726e-07 1.07992929e-07
#  1.05609775e-07 1.03279077e-07 1.00999677e-07 9.87704405e-08
#  9.65902601e-08 9.44580464e-08 9.23727609e-08 9.03333894e-08
#  8.83389359e-08 8.63884227e-08 8.44808900e-08 8.26153963e-08
#  8.07910182e-08 7.90068504e-08 7.72620057e-08 7.55556153e-08
#  7.38868282e-08 7.22548118e-08 7.06587515e-08 6.90978508e-08
#  6.75713316e-08 6.60784299e-08 6.46184021e-08 6.31905400e-08
#  6.17941489e-08 6.04285463e-08 5.90930623e-08 5.77870387e-08
#  5.65098302e-08 5.52608033e-08 5.40393370e-08 5.28448226e-08
#  5.16766636e-08 5.05342758e-08 4.94170872e-08 4.83245382e-08
#  4.72560815e-08 4.62111819e-08 4.51893166e-08 4.41899703e-08
#  4.32126488e-08 4.22568792e-08 4.13221966e-08 4.04081444e-08
#  3.95142739e-08 3.86401444e-08 3.77853236e-08 3.69493870e-08
#  3.61319183e-08 3.53325091e-08 3.45507594e-08 3.37862770e-08
#  3.30386779e-08 3.23075862e-08 3.15926339e-08 3.08934613e-08
#  3.02097166e-08 2.95410564e-08 2.88871411e-08 2.82476477e-08
#  2.76222676e-08 2.70106977e-08 2.64126395e-08 2.58278000e-08
#  2.52558913e-08 2.46966306e-08 2.41497402e-08 2.36149476e-08
#  2.30919855e-08 2.25805916e-08 2.20805088e-08 2.15914851e-08
#  2.11132738e-08 2.06456332e-08 2.01883268e-08 1.97411231e-08
#  1.93037960e-08 1.88761244e-08 1.84578910e-08 1.80488844e-08
#  1.76489079e-08 1.72577687e-08 1.68752773e-08 1.65012471e-08
#  1.61354949e-08 1.57778404e-08 1.54281067e-08 1.50861199e-08
#  1.47517092e-08 1.44247071e-08 1.41049491e-08 1.37922739e-08
#  1.34865234e-08 1.31875426e-08 1.28951795e-08 1.26092855e-08
#  1.23297150e-08 1.20563255e-08 1.17889779e-08 1.15275359e-08
#  1.12718658e-08 1.10218377e-08 1.07773318e-08 1.05382314e-08
#  1.03044211e-08 1.00757877e-08 9.85221975e-09 9.63360750e-09
#  9.41984318e-09 9.21082080e-09 9.00643621e-09 8.80658709e-09
#  8.61117296e-09 8.42009517e-09 8.23325690e-09 8.05056319e-09
#  7.87192087e-09 7.69723864e-09 7.52642701e-09 7.35939835e-09
#  7.19606683e-09 7.03634849e-09 6.88016118e-09 6.72742459e-09
#  6.57805978e-09 6.43199063e-09 6.28914800e-09 6.14946428e-09
#  6.01287282e-09 5.87930801e-09 5.74870525e-09 5.62100092e-09
#  5.49613244e-09 5.37403822e-09 5.25465767e-09 5.13793123e-09
#  5.02380034e-09 4.91220744e-09 4.80309598e-09 4.69641043e-09
#  4.59209624e-09 4.49009990e-09 4.39036890e-09 4.29285171e-09
#  4.19749785e-09 4.10425783e-09 4.01308314e-09 3.92392633e-09
#  3.83674092e-09 3.75148145e-09 3.66810380e-09 3.58657285e-09
#  3.50685089e-09 3.42889786e-09 3.35267458e-09 3.27814273e-09]

# %% [markdown]
# ### Controller validation
#
# The goal of this part is to test the controller on the **true** non linear system.
#
# We are going to simulate the original `fun` function, but to do this, we need to define a new version of the function `omega` that computes the wheel velocities given `t` and `xytheta` (the value of the state at time `t`).
#
# 🧩 Implement this new version of `omega`.

# %%
pass

# %% [markdown]
# 🧩 Simulate the true system during 20 sec using the pole placement controller designed during the 'Controller Tuning'.

# %%
pass

# %% [markdown]
# 🧩 Plot $x(t)$, $y(t)$, $\theta(t)$, $\omega_l(t)$ and $\omega_r(t)$.

# %%
pass

# %% [markdown]
# 🧩 Use the simulation results to display the wheelchair location every 1 second.

# %%
pass

# %% [markdown]
# 🧩 Make a similar drawing but add to the wheelchair real location the wheelchair reference location in the background; use the blue color to represent this "virtual" weelchair.

# %%
pass

# %% [markdown]
# 🧩 We now aim to compare the different control strategies. We consider the pole placement strategy and two optimal controllers (one with a large $Q$ and one with a large $R$). Run the simulations with the these extreme controllers, then with the controller that met the design constraints when tested on the linear model. Adjust slightly the parameters of the latter model if the constraints are not met anymore, so that they are met again.

# %%
pass

# %% [markdown]
# 🧩 Your wheelchair faces some strong wind (constant speed). How can you model the effect of this wind? Show the impact on the performance of your controller (with your controller of your choice).

# %%
pass

# %% [markdown]
# 🧩 What happens if the controller brutally stops at t=10s?

# %%
pass

# %% [markdown]
# 🧩 What if additionally to the initial position mismatch the wheelchair starts with a wrong orientation (say $\theta=\pi/2$)?

# %%
pass

# %% [markdown]
# ###  Feet Dynamics
#
# The person in the wheelchair now tries to control its vehicle by targetting only where should be the location between its feet ($M=20$ cm in front of the weelchair seet) without any regard for the wheelchair angle.

# %% [markdown]
# 🧩 Write the coordinates $(x_f, y_f)$ of this location as a function of $x$, $y$ and $\theta$.

# %% [markdown]
# **Answer:**

# %% [markdown]
# 🧩 Write the differential equation satisfied by $(x_f, y_f)$.

# %% [markdown]
# **Answer:**

# %% [markdown]
# 🧩 Show any (smooth) reference evolution of the person feet $(x_f^r(t), y_f^r(t))$ and any initial state of the wheelchair consistent with the initial feet location, there is an admissible trajectory $(x(t), y(t), \theta(t))$ that corresponds to this reference. Hint: search the unique $\omega_l(t)$ and $\omega_r(t)$ -- as functions of $\dot{x}_f^r(t)$, $\dot{y}_f^r(t)$ and $\theta(t)$ -- that satisfies this property.

# %% [markdown]
# **Answer:**

# %% [markdown]
# 🧩 Let $v>0$ be the value in m/s that corresponds to $4.8$ km/h and let $(x_f^r(t), y_f^r(t)) = (vt, 0)$.
# Simulate the wheelchair evolution with the choice for $\omega_l$ and $\omega_r$ of the previous question for $X(0) = (-L-M, 0, 0)$. Represent the wheelchair every second with an extra dot for the feet location.
#
# Then, try the simulation with
# $$
# X(0) = (-(L+M)\cos(\alpha), -(L+M)\sin(\alpha),\alpha)
# $$
# for different values of $\alpha = \theta(0)$. In particular, investigate the case of à $\theta(0)$ close to $0$, then close to $\pi$). Is the system dynamics asymptotically stable in each case?

# %%
pass

# %% [markdown]
# 🧩 Consider three pillars (of small radius) whose centers are aligned and distant of 2 meters, say at the locations
# $$
# (1.0,0), (3.0, 0) \mbox{ and } (5.0,0).
# $$
# Compute a reference trajectory trajectory that would lead the feetfrom $(0,0)$ to $(6,0)$ with a slalom between the pillars. Of course, you don't want the robot frame to bump into the pillars ! Display this trajectory graphically. What happens when if the inputs $\omega_l(t)$ and $\omega_r(t)$ are applied but the robot is not initially at the expected position ?

# %% [markdown]
# **Answer:**

# %%
pass
